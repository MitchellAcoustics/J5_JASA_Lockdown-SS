# %% [markdown]
# # London Lockdown Multilevel Model
#
# ## Load Data

# %%
import pandas as pd
import statsmodels.api as sm
from pathlib import Path
import itertools
import matplotlib.pyplot as plt
import numpy as np
import pingouin as pg
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning

import statsmodels.api as sm
import statsmodels.formula.api as smf
# %matplotlib inline

warnings.simplefilter('ignore', ConvergenceWarning)

DATA_DIR = Path("C:\\Users\\Andrew\\OneDrive - University College London\\_PhD\\Papers - Drafts\\J5_JASA_Lockdown-SS\\data")
ssidData = pd.read_csv(DATA_DIR.joinpath("2020-08-13\\LondonVeniceBINResults_2020-08-13_4.csv"))
ssidData.head()
# Out:
#    Unnamed: 0 GroupID    SessionID  LocationID  record_id recording  \
# 0           0   CT101  CamdenTown1  CamdenTown      525.0   11-42_1
# 1           1   CT101  CamdenTown1  CamdenTown      526.0   11-42_1
# 2           2   CT101  CamdenTown1  CamdenTown      561.0   11-42_1
# 3           3   CT102  CamdenTown1  CamdenTown      560.0   11-50_2
# 4           4   CT103  CamdenTown1  CamdenTown      527.0   11-52_3
#
#          start_time          end_time   latitude  longitude  ...  THD_5  \
# 0  2019-05-02 11:40  2019-05-02 11:43  51.539124  -0.142624  ...   3.13
# 1  2019-05-02 11:41  2019-05-02 11:44  51.539124  -0.142624  ...   3.13
# 2  2019-05-02 11:40  2019-05-02 11:43        NaN        NaN  ...   3.13
# 3  2019-05-02 11:50  2019-05-02 11:53        NaN        NaN  ...   3.09
# 4  2019-05-02 11:49  2019-05-02 11:54  51.539124  -0.142624  ...   3.16
#
#    THD_10  THD_50  THD_90  THD_95  THD_Min  THD_Max  THD_5_THD_95  \
# 0    2.33   -0.45   -4.52   -5.58   -10.77     5.45          8.71
# 1    2.33   -0.45   -4.52   -5.58   -10.77     5.45          8.71
# 2    2.33   -0.45   -4.52   -5.58   -10.77     5.45          8.71
# 3    2.52    0.28   -2.39   -3.37    -7.04     5.72          6.46
# 4    2.40   -0.15   -3.17   -4.15    -7.91     5.59          7.31
#
#    THD_10_THD_90  THD_Max_THD_Min
# 0           6.85            16.22
# 1           6.85            16.22
# 2           6.85            16.22
# 3           4.91            12.76
# 4           5.57            13.50
#
# [5 rows x 272 columns]

# %% [markdown]
# ## Reshape, standardise, and filter the data

# %%
for col_name in ["Lockdown"]:
    ssidData[col_name] = ssidData[col_name].astype('category')

acoustic_vars = ["FS", "FS_5", "FS_10", "FS_50", "FS_90", "FS_95", "FS_Min", "FS_Max", "FS_5_FS_95", "FS_10_FS_90", "FS_Max_FS_Min", "LAeq", "LAeq_5", "LAeq_10", "LAeq_50", "LAeq_90", "LAeq_95", "LAeq_Max", "LAeq_Min", "LAeq_10_LAeq_90", "LAeq_5_LAeq_95", "LAeq_Max_LAeq_Min", "N_5", "N_10", "N_50", "N_90", "N_95", "N_Min", "N_Max", "N_5_N_95", "N_10_N_90", "N_Max_N_Min", "R", "R_5", "R_10", "R_50", "R_90", "R_95", "R_Min", "R_Max", "R_5_R_95", "R_10_R_90", "R_Max_R_Min", "S", "S_5", "S_10", "S_50", "S_90", "S_95", "S_Min", "S_Max", "S_5_S_95", "S_10_S_90", "S_Max_S_Min", "SIL_5", "SIL_10", "SIL_50", "SIL_90", "SIL_95", "SIL_Min", "SIL_Max", "SIL_5_SIL_95", "SIL_10_SIL_90", "SIL_Max_SIL_Min", "T_5", "T_10", "T_50", "T_90", "T_95", "T_Max", "T_5_T_95", "T_10_T_90", "SpectralCentroid", "MaxFreq", "PeakSpectralCentroid", "PeakMaxFreq", "I","I_5","I_10","I_50","I_90","I_95","I_Min","I_Max","I_5_I_95","I_10_I_90","I_Max_I_Min", "LCeq","LCeq_5","LCeq_10","LCeq_50","LCeq_90","LCeq_95","LCeq_Min","LCeq_Max","LCeq_5_LCeq_95","LCeq_10_LCeq_90","LCeq_Max_LCeq_Min", "LZeq","LZeq_5","LZeq_10","LZeq_50","LZeq_90","LZeq_95","LZeq_Min","LZeq_Max","LZeq_5_LZeq_95","LZeq_10_LZeq_90","LZeq_Max_LZeq_Min", "THD_5","THD_10","THD_50","THD_90","THD_95","THD_Min","THD_Max", "THD_5_THD_95","THD_10_THD_90","THD_Max_THD_Min"]

# "FS_M0", "FS_nrmse0", "LAeq_M0", "LAeq_nrmse0", "N_M0", "N_nrmse0", "N_M1", "N_nrmse1", "N_M2", "N_nrmse2", "R_M0", "R_nrmse0", "S_M0", "S_nrmse0", "S_M1", "S_nrmse1", "S_M2", "S_nrmse2", "SIL_M0", "SIL_nrmse0", "T_M0", "T_nrmse0",

dep_vars = ["Natural", "Traffic", "Human", "Other", "overall", "Pleasant", "Eventful"]

# Cutdown the dataset
cols = ["GroupID", "LocationID", "SessionID", "Lockdown"] + dep_vars + acoustic_vars
ssidData = ssidData[cols]

# Compress to mean of each GroupID
# compressData = ssidData.copy()
compressData = ssidData.groupby(["GroupID"]).mean()
compressData = compressData.merge(ssidData[["GroupID", "LocationID", "SessionID", "Lockdown"]].drop_duplicates(),  on="GroupID")

location_codes = pd.Categorical(compressData["LocationID"]).codes
compressData["LocationID_codes"] = location_codes
compressData.loc[compressData["Lockdown"] == 1].dropna(inplace=True)
compressData = compressData.dropna(subset=acoustic_vars)

print(compressData.shape)
compressData.head()
# Out:
# (1235, 131)
#   GroupID   Natural   Traffic  Human     Other   overall  Pleasant  Eventful  \
# 1    AM02  3.500000  2.000000    4.0  1.500000  4.500000  0.426777  0.000000
# 4    AM06  1.500000  1.000000    3.5  4.000000  3.000000  0.176777  0.103553
# 5    AM07  4.000000  1.000000    4.0  1.000000  5.000000  0.707107  0.707107
# 6   CT101  1.666667  3.666667    3.0  2.333333  2.666667 -0.229780  0.284518
# 7   CT102  1.000000  3.000000    4.0  2.000000  2.000000  0.103553 -0.750000
#
#        FS    FS_5  ...  THD_95  THD_Min  THD_Max  THD_5_THD_95  THD_10_THD_90  \
# 1  0.0215  0.0376  ...    2.31    -1.18     9.11          4.80           3.64
# 4  0.0283  0.0495  ...    1.17    -3.63     7.73          4.59           3.50
# 5  0.0178  0.0353  ...    1.59    -0.77     9.20          5.28           4.15
# 6  0.0170  0.0317  ...   -5.58   -10.77     5.45          8.71           6.85
# 7  0.0179  0.0409  ...   -3.37    -7.04     5.72          6.46           4.91
#
#    THD_Max_THD_Min  LocationID    SessionID  Lockdown  LocationID_codes
# 1            10.29    SanMarco    SanMarco1         1                 8
# 4            11.36    SanMarco    SanMarco1         1                 8
# 5             9.97    SanMarco    SanMarco1         1                 8
# 6            16.22  CamdenTown  CamdenTown1         1                 0
# 7            12.76  CamdenTown  CamdenTown1         1                 0
#
# [5 rows x 131 columns]

# %%
def nonlinear_features(data, features, transformations = ["sqrt", "square"]):
    new_acoustic_vars = []
    for feature in features:
        new_acoustic_vars.append(feature)
        if feature in ["FS_5_FS_95", "FS_10_FS_90", "FS_Max_FS_Min", 
                        "LAeq_5_LAeq_90", "LAeq_10_LAeq_90", "LAeq_Max_LAeq_Min", 
                        "N_5_N_95", "N_10_N_90", "N_Max_N_Min",
                        "R_5_R_95", "R_10_R_90", "R_Max_R_Min",
                        "S_5_S_95", "S_10_S_90", "S_Max_S_Min",
                        "SIL_5_SIL_95", "SIL_10_SIL_90", "SIL_Max_SIL_Min",
                        "T_5_T_95", "T_10_T_90",
                        "LZeq_5_LZeq_95", "LZeq_10_LZeq_90", "LZeq_Max_LZeq_Min",
                        "LCeq_5_LCeq_95", "LCeq_10_LCeq_90", "LCeq_Max_LCeq_Min",
                        "THD_5_THD_95", "THD_10_THD_90", "THD_Max_THD_Min"
                        ]:
            continue
        if "THD" in feature:
            continue

        for transform in transformations:
            if transform == "log":
                transform_feature = f"log_{feature}"
                transform_val = np.log(data[feature])
            elif transform == "square":
                transform_feature = f"sq_{feature}"
                transform_val = np.square(data[feature])
            elif transform == "sqrt":
                if any(data[feature]) < 0:
                    break
                else:
                    transform_feature = f"sqrt_{feature}"
                    transform_val = np.sqrt(data[feature])
            else:
                print(f"Transformation not recognised: {transform}")
                continue
            
            if not transform_val.isnull().values.all():
                data[transform_feature] = transform_val
                new_acoustic_vars.append(transform_feature)

    return data, new_acoustic_vars

compressData, acoustic_vars = nonlinear_features(compressData, acoustic_vars, transformations=["log", "square"])
print(acoustic_vars)
compressData.head()
# Out:
# ['FS', 'log_FS', 'sq_FS', 'FS_5', 'log_FS_5', 'sq_FS_5', 'FS_10', 'log_FS_10', 'sq_FS_10', 'FS_50', 'log_FS_50', 'sq_FS_50', 'FS_90', 'log_FS_90', 'sq_FS_90', 'FS_95', 'log_FS_95', 'sq_FS_95', 'FS_Min', 'log_FS_Min', 'sq_FS_Min', 'FS_Max', 'log_FS_Max', 'sq_FS_Max', 'FS_5_FS_95', 'FS_10_FS_90', 'FS_Max_FS_Min', 'LAeq', 'log_LAeq', 'sq_LAeq', 'LAeq_5', 'log_LAeq_5', 'sq_LAeq_5', 'LAeq_10', 'log_LAeq_10', 'sq_LAeq_10', 'LAeq_50', 'log_LAeq_50', 'sq_LAeq_50', 'LAeq_90', 'log_LAeq_90', 'sq_LAeq_90', 'LAeq_95', 'log_LAeq_95', 'sq_LAeq_95', 'LAeq_Max', 'log_LAeq_Max', 'sq_LAeq_Max', 'LAeq_Min', 'log_LAeq_Min', 'sq_LAeq_Min', 'LAeq_10_LAeq_90', 'LAeq_5_LAeq_95', 'log_LAeq_5_LAeq_95', 'sq_LAeq_5_LAeq_95', 'LAeq_Max_LAeq_Min', 'N_5', 'log_N_5', 'sq_N_5', 'N_10', 'log_N_10', 'sq_N_10', 'N_50', 'log_N_50', 'sq_N_50', 'N_90', 'log_N_90', 'sq_N_90', 'N_95', 'log_N_95', 'sq_N_95', 'N_Min', 'log_N_Min', 'sq_N_Min', 'N_Max', 'log_N_Max', 'sq_N_Max', 'N_5_N_95', 'N_10_N_90', 'N_Max_N_Min', 'R', 'log_R', 'sq_R', 'R_5', 'log_R_5', 'sq_R_5', 'R_10', 'log_R_10', 'sq_R_10', 'R_50', 'log_R_50', 'sq_R_50', 'R_90', 'log_R_90', 'sq_R_90', 'R_95', 'log_R_95', 'sq_R_95', 'R_Min', 'log_R_Min', 'sq_R_Min', 'R_Max', 'log_R_Max', 'sq_R_Max', 'R_5_R_95', 'R_10_R_90', 'R_Max_R_Min', 'S', 'log_S', 'sq_S', 'S_5', 'log_S_5', 'sq_S_5', 'S_10', 'log_S_10', 'sq_S_10', 'S_50', 'log_S_50', 'sq_S_50', 'S_90', 'log_S_90', 'sq_S_90', 'S_95', 'log_S_95', 'sq_S_95', 'S_Min', 'log_S_Min', 'sq_S_Min', 'S_Max', 'log_S_Max', 'sq_S_Max', 'S_5_S_95', 'S_10_S_90', 'S_Max_S_Min', 'SIL_5', 'log_SIL_5', 'sq_SIL_5', 'SIL_10', 'log_SIL_10', 'sq_SIL_10', 'SIL_50', 'log_SIL_50', 'sq_SIL_50', 'SIL_90', 'log_SIL_90', 'sq_SIL_90', 'SIL_95', 'log_SIL_95', 'sq_SIL_95', 'SIL_Min', 'log_SIL_Min', 'sq_SIL_Min', 'SIL_Max', 'log_SIL_Max', 'sq_SIL_Max', 'SIL_5_SIL_95', 'SIL_10_SIL_90', 'SIL_Max_SIL_Min', 'T_5', 'log_T_5', 'sq_T_5', 'T_10', 'log_T_10', 'sq_T_10', 'T_50', 'log_T_50', 'sq_T_50', 'T_90', 'log_T_90', 'sq_T_90', 'T_95', 'log_T_95', 'sq_T_95', 'T_Max', 'log_T_Max', 'sq_T_Max', 'T_5_T_95', 'T_10_T_90', 'SpectralCentroid', 'log_SpectralCentroid', 'sq_SpectralCentroid', 'MaxFreq', 'log_MaxFreq', 'sq_MaxFreq', 'PeakSpectralCentroid', 'log_PeakSpectralCentroid', 'sq_PeakSpectralCentroid', 'PeakMaxFreq', 'log_PeakMaxFreq', 'sq_PeakMaxFreq', 'I', 'log_I', 'sq_I', 'I_5', 'log_I_5', 'sq_I_5', 'I_10', 'log_I_10', 'sq_I_10', 'I_50', 'log_I_50', 'sq_I_50', 'I_90', 'log_I_90', 'sq_I_90', 'I_95', 'log_I_95', 'sq_I_95', 'I_Min', 'log_I_Min', 'sq_I_Min', 'I_Max', 'log_I_Max', 'sq_I_Max', 'I_5_I_95', 'log_I_5_I_95', 'sq_I_5_I_95', 'I_10_I_90', 'log_I_10_I_90', 'sq_I_10_I_90', 'I_Max_I_Min', 'log_I_Max_I_Min', 'sq_I_Max_I_Min', 'LCeq', 'log_LCeq', 'sq_LCeq', 'LCeq_5', 'log_LCeq_5', 'sq_LCeq_5', 'LCeq_10', 'log_LCeq_10', 'sq_LCeq_10', 'LCeq_50', 'log_LCeq_50', 'sq_LCeq_50', 'LCeq_90', 'log_LCeq_90', 'sq_LCeq_90', 'LCeq_95', 'log_LCeq_95', 'sq_LCeq_95', 'LCeq_Min', 'log_LCeq_Min', 'sq_LCeq_Min', 'LCeq_Max', 'log_LCeq_Max', 'sq_LCeq_Max', 'LCeq_5_LCeq_95', 'LCeq_10_LCeq_90', 'LCeq_Max_LCeq_Min', 'LZeq', 'log_LZeq', 'sq_LZeq', 'LZeq_5', 'log_LZeq_5', 'sq_LZeq_5', 'LZeq_10', 'log_LZeq_10', 'sq_LZeq_10', 'LZeq_50', 'log_LZeq_50', 'sq_LZeq_50', 'LZeq_90', 'log_LZeq_90', 'sq_LZeq_90', 'LZeq_95', 'log_LZeq_95', 'sq_LZeq_95', 'LZeq_Min', 'log_LZeq_Min', 'sq_LZeq_Min', 'LZeq_Max', 'log_LZeq_Max', 'sq_LZeq_Max', 'LZeq_5_LZeq_95', 'LZeq_10_LZeq_90', 'LZeq_Max_LZeq_Min', 'THD_5', 'THD_10', 'THD_50', 'THD_90', 'THD_95', 'THD_Min', 'THD_Max', 'THD_5_THD_95', 'THD_10_THD_90', 'THD_Max_THD_Min']
#   GroupID   Natural   Traffic  Human     Other   overall  Pleasant  Eventful  \
# 1    AM02  3.500000  2.000000    4.0  1.500000  4.500000  0.426777  0.000000
# 4    AM06  1.500000  1.000000    3.5  4.000000  3.000000  0.176777  0.103553
# 5    AM07  4.000000  1.000000    4.0  1.000000  5.000000  0.707107  0.707107
# 6   CT101  1.666667  3.666667    3.0  2.333333  2.666667 -0.229780  0.284518
# 7   CT102  1.000000  3.000000    4.0  2.000000  2.000000  0.103553 -0.750000
#
#        FS    FS_5  ...  log_LZeq_50  sq_LZeq_50  log_LZeq_90  sq_LZeq_90  \
# 1  0.0215  0.0376  ...     4.281515   5234.5225     4.253483   4949.1225
# 4  0.0283  0.0495  ...     4.285653   5278.0225     4.265493   5069.4400
# 5  0.0178  0.0353  ...     4.257313   4987.1844     4.239454   4812.1969
# 6  0.0170  0.0317  ...     4.367547   6217.3225     4.308246   5521.9761
# 7  0.0179  0.0409  ...     4.369448   6241.0000     4.319486   5647.5225
#
#    log_LZeq_95  sq_LZeq_95  log_LZeq_Min  sq_LZeq_Min  log_LZeq_Max  \
# 1     4.246493   4880.4196      4.233817    4758.2404      4.352212
# 4     4.257455   4988.5969      4.235844    4777.5744      4.365389
# 5     4.234107   4761.0000      4.222005    4647.1489      4.318421
# 6     4.292375   5349.4596      4.244344    4859.4841      4.464528
# 7     4.310665   5548.7601      4.278609    5204.1796      4.486499
#
#    sq_LZeq_Max
# 1    6029.5225
# 4    6190.5424
# 5    5635.5049
# 6    7548.1344
# 7    7887.2161
#
# [5 rows x 299 columns]

# %%
# Standardise
from sklearn.preprocessing import StandardScaler
compressData = compressData.replace([np.inf, -np.inf], np.nan)
compressData = compressData.dropna(subset=acoustic_vars)
scaler = StandardScaler()
compressData[acoustic_vars] = scaler.fit_transform(compressData[acoustic_vars])
print(compressData.shape)
compressData.head()
# Out:
# (1210, 299)
#   GroupID   Natural   Traffic  Human     Other   overall  Pleasant  Eventful  \
# 1    AM02  3.500000  2.000000    4.0  1.500000  4.500000  0.426777  0.000000
# 4    AM06  1.500000  1.000000    3.5  4.000000  3.000000  0.176777  0.103553
# 5    AM07  4.000000  1.000000    4.0  1.000000  5.000000  0.707107  0.707107
# 6   CT101  1.666667  3.666667    3.0  2.333333  2.666667 -0.229780  0.284518
# 7   CT102  1.000000  3.000000    4.0  2.000000  2.000000  0.103553 -0.750000
#
#          FS      FS_5  ...  log_LZeq_50  sq_LZeq_50  log_LZeq_90  sq_LZeq_90  \
# 1  0.398275 -0.029090  ...     0.278129    0.204259     0.463989    0.401412
# 4  0.837595  0.227903  ...     0.327197    0.256536     0.605221    0.557101
# 5  0.159234 -0.078761  ...    -0.008864   -0.092984     0.299024    0.224232
# 6  0.107549 -0.156506  ...     1.298310    1.385356     1.107971    1.142678
# 7  0.165694  0.042177  ...     1.320847    1.413811     1.240154    1.305133
#
#    log_LZeq_95  sq_LZeq_95  log_LZeq_Min  sq_LZeq_Min  log_LZeq_Max  \
# 1     0.488439    0.427802      0.651256     0.608134     -0.431687
# 4     0.616486    0.569513      0.674140     0.634091     -0.281906
# 5     0.343746    0.271364      0.517938     0.458989     -0.815764
# 6     1.024402    1.042238      0.770073     0.744058      0.844948
# 7     1.238046    1.303319      1.156809     1.206827      1.094684
#
#    sq_LZeq_Max
# 1    -0.501676
# 4    -0.361431
# 5    -0.844858
# 6     0.821004
# 7     1.116338
#
# [5 rows x 299 columns]

# %% [markdown]
# Split into pre- and during-lockdown datasets

# %%
prelockdownData = compressData.loc[compressData["Lockdown"] == 1]
prelockdownData = prelockdownData.dropna()
print(prelockdownData.shape)
prelockdownData.head()
# Out:
# (644, 299)
#   GroupID   Natural   Traffic  Human     Other   overall  Pleasant  Eventful  \
# 1    AM02  3.500000  2.000000    4.0  1.500000  4.500000  0.426777  0.000000
# 4    AM06  1.500000  1.000000    3.5  4.000000  3.000000  0.176777  0.103553
# 5    AM07  4.000000  1.000000    4.0  1.000000  5.000000  0.707107  0.707107
# 6   CT101  1.666667  3.666667    3.0  2.333333  2.666667 -0.229780  0.284518
# 7   CT102  1.000000  3.000000    4.0  2.000000  2.000000  0.103553 -0.750000
#
#          FS      FS_5  ...  log_LZeq_50  sq_LZeq_50  log_LZeq_90  sq_LZeq_90  \
# 1  0.398275 -0.029090  ...     0.278129    0.204259     0.463989    0.401412
# 4  0.837595  0.227903  ...     0.327197    0.256536     0.605221    0.557101
# 5  0.159234 -0.078761  ...    -0.008864   -0.092984     0.299024    0.224232
# 6  0.107549 -0.156506  ...     1.298310    1.385356     1.107971    1.142678
# 7  0.165694  0.042177  ...     1.320847    1.413811     1.240154    1.305133
#
#    log_LZeq_95  sq_LZeq_95  log_LZeq_Min  sq_LZeq_Min  log_LZeq_Max  \
# 1     0.488439    0.427802      0.651256     0.608134     -0.431687
# 4     0.616486    0.569513      0.674140     0.634091     -0.281906
# 5     0.343746    0.271364      0.517938     0.458989     -0.815764
# 6     1.024402    1.042238      0.770073     0.744058      0.844948
# 7     1.238046    1.303319      1.156809     1.206827      1.094684
#
#    sq_LZeq_Max
# 1    -0.501676
# 4    -0.361431
# 5    -0.844858
# 6     0.821004
# 7     1.116338
#
# [5 rows x 299 columns]

# %%
lockdownData = compressData.loc[compressData["Lockdown"] == 2]
print(lockdownData.shape)
lockdownData.head()
# Out:
# (565, 299)
#    GroupID  Natural  Traffic  Human  Other  overall  Pleasant  Eventful  \
# 63   CT501      NaN      NaN    NaN    NaN      NaN       NaN       NaN
# 64   CT502      NaN      NaN    NaN    NaN      NaN       NaN       NaN
# 65   CT503      NaN      NaN    NaN    NaN      NaN       NaN       NaN
# 66   CT504      NaN      NaN    NaN    NaN      NaN       NaN       NaN
# 67   CT505      NaN      NaN    NaN    NaN      NaN       NaN       NaN
#
#           FS      FS_5  ...  log_LZeq_50  sq_LZeq_50  log_LZeq_90  sq_LZeq_90  \
# 63 -0.538509 -0.573309  ...     0.202494    0.124521    -0.079958   -0.164467
# 64 -0.566936 -0.547394  ...     0.819560    0.805756     0.615127    0.568162
# 65 -0.092729  0.476257  ...     1.896550    2.178598     1.912221    2.190044
# 66  0.185076  0.029219  ...     0.405286    0.340629     0.412056    0.345096
# 67 -0.254244 -0.227773  ...     0.964297    0.976074     0.816372    0.796955
#
#     log_LZeq_95  sq_LZeq_95  log_LZeq_Min  sq_LZeq_Min  log_LZeq_Max  \
# 63    -0.111965   -0.196760     -0.026450    -0.114744      0.490154
# 64     0.613178    0.565812      0.603706     0.554534      1.282542
# 65     1.896579    2.170865      1.594123     1.769783      1.607674
# 66     0.394424    0.325715      0.431513     0.364170     -0.148343
# 67     0.664350    0.623287      0.406460     0.336953      1.247239
#
#     sq_LZeq_Max
# 63     0.423132
# 64     1.347207
# 65     1.765263
# 66    -0.233215
# 67     1.303236
#
# [5 rows x 299 columns]

# %% [markdown]
# ## Global Functions

# %%
def r_squared(model_fit, data):
    response = model_fit.model.formula.split()[0]
    y = data[response]
    y_predict = model_fit.fittedvalues
    RMSE = np.sqrt(((y - y_predict)**2).values.mean())
    Rsquared = 1.0 - (np.var(y - y_predict) / np.var(y))
    return Rsquared

def adjusted_r_squared(model_fit, data):
    response = model_fit.model.formula.split()[0]
    y = data[response]
    y_predict = model_fit.fittedvalues
    r_sq = r_squared(model_fit, data)
    adjusted_r_squared = 1 - (1 - r_sq) * (len(y)-1)/(len(y)-len(model_fit.fe_params)-1)
    return adjusted_r_squared

def max_pcor(feature_list, target_feature, covar, data):
    cors_table = pd.DataFrame()
    for feature in feature_list:
        par_cor = pg.partial_corr(data, x=feature, y = target_feature, covar=covar)
        cors_table[feature] = par_cor['r']
    
    cors_table = cors_table.T.squeeze()

    max_feature = cors_table.abs().idxmax()
    max_val = cors_table[max_feature]

    return max_feature, max_val

FS_stats = ["FS", "FS_5", "FS_10", "FS_50", "FS_90", "FS_95", "FS_Min", "FS_Max"]
FS_variation = ["FS_5_FS_95", "FS_10_FS_90", "FS_Max_FS_Min"]
LAeq_stats = ["LAeq", "LAeq_5", "LAeq_10", "LAeq_50", "LAeq_90", "LAeq_95", "LAeq_Max", "LAeq_Min"]
LAeq_variation = ["LAeq_10_LAeq_90", "LAeq_5_LAeq_95", "LAeq_Max_LAeq_Min"]
N_stats = ["N_5", "N_10", "N_50", "N_90", "N_95", "N_Min", "N_Max"]
N_variation = ["N_5_N_95", "N_10_N_90", "N_Max_N_Min"]
R_stats = ["R", "R_5", "R_10", "R_50", "R_90", "R_95", "R_Min", "R_Max"]
R_variation = ["R_5_R_95", "R_10_R_90", "R_Max_R_Min"]
S_stats = ["S", "S_5", "S_10", "S_50", "S_90", "S_95", "S_Min", "S_Max"]
S_variation = ["S_5_S_95", "S_10_S_90", "S_Max_S_Min"]
SIL_stats = ["SIL_5", "SIL_10", "SIL_50", "SIL_90", "SIL_95", "SIL_Min", "SIL_Max"]
SIL_variation = ["SIL_5_SIL_95", "SIL_10_SIL_90", "SIL_Max_SIL_Min"]
T_stats = ["T_5", "T_10", "T_50", "T_90", "T_95", "T_Max"]
T_variation = ["T_5_T_95", "T_10_T_90"]
I_stats = ["I","I_5","I_10","I_50","I_90","I_95","I_Min","I_Max"]
I_variation = ["I_5_I_95","I_10_I_90","I_Max_I_Min"]
LCeq_stats = ["LCeq","LCeq_5","LCeq_10","LCeq_50","LCeq_90","LCeq_95","LCeq_Min","LCeq_Max"]
LCeq_variation = ["LCeq_5_LCeq_95","LCeq_10_LCeq_90","LCeq_Max_LCeq_Min"]
LZeq_stats = ["LZeq","LZeq_5","LZeq_10","LZeq_50","LZeq_90","LZeq_95","LZeq_Min","LZeq_Max"]
LZeq_variation = ["LZeq_5_LZeq_95","LZeq_10_LZeq_90","LZeq_Max_LZeq_Min"]
THD_stats = ["THD_5","THD_10","THD_50","THD_90","THD_95","THD_Min","THD_Max"]
THD_variation = ["THD_5_THD_95","THD_10_THD_90","THD_Max_THD_Min"]


frequency_features = ["SpectralCentroid", "MaxFreq", "PeakSpectralCentroid", "PeakMaxFreq"]

all_features = [FS_stats, FS_variation, LAeq_stats, LAeq_variation, LCeq_stats, LCeq_variation, LZeq_stats, LZeq_variation, N_stats, N_variation, R_stats, R_variation, S_stats, S_variation, SIL_stats, SIL_variation, T_stats, T_variation, I_stats, I_variation, THD_stats, THD_variation, frequency_features]

# %% [markdown]
# ## Feature Selection and Model Building
# ### Partial correlation filtering
# With this filtering method, we run a partial correlation for each type of feature. For instance, we have several LAeq statistics measures (LAeq, LAeq_5, LAeq_10, etc). We know we won't want to use all of them, so we determine which feature within each type subset has the highest correlation value (when controlling for LocationID) and use that one.
#
# This results in a list of candidate features, ready to go through further feature selection.
#
# **This method has been replaced with the backward step feature selection, based on p-values** but is left in since it is useful.

# %%
# Natural_features = {}
# for item in all_features:
#     feature, val = max_pcor(item, "Natural", ["LocationID_codes"], prelockdownData)
#     Natural_features[feature] = val
# Natural_features

# %% [markdown]
# ### Backward step feature selection
# In order to filter out the massive number of potential features, we want to determine which ones significantly contribute to the final model. To do this, we use backward step feature selection which starts by including all possible features and gradually reduces them based on their p-values. This follows 6 steps:
#
# ![](https://miro.medium.com/max/700/1*Jub_nEYtN0htxFpTRzRtBQ.png)
#
# #### Step 1
# Select a significance level to use as the criterion for selection. Typically, this will be 0.05.
#
# #### Step 2
# Fit the model with all the features selected.
#
# #### Step 3
# Identify the feature with the highest p-value (i.e. least statistically significant).
#
# #### Step 4
# If the p-value of this feature is greater than the significance level (e.g. p-value is > 0.05), we remove it from the feature set. If the highest p-value is less than the significance level, skip to step 6 and finish.
#
# #### Step 5
# Remove the feature from the set and fit a new model. Return to step 3 and repeat until all features have a p-value below the significance level.
#
# #### Step 6
# We have now identified the feature set, so fit the final model.

# %%
from numpy.linalg import LinAlgError

def mlm_backward_step(data, response, features, groups, sig_level = 0.05, verbose=False):
    data = data[[response, groups] + features] # Cut down the dataset to just what is required
    remaining = features.copy() # Avoid overwriting initial features list

    while remaining:
        # Step 2: fit the model with all features
        try:
            init_formula = "{} ~ {}".format(response, ' + '.join(remaining))
            init_model = smf.mixedlm(init_formula, data, groups = groups).fit(reml=False)
        except LinAlgError as error:
            # Sometimes a singular matrix error is raised when fitting the model. 
            # For now, to handle it we just go ahead and remove the next highest pval as well and move on
            next_least_sig_feature = pvals.nlargest(count+2).index[-1]
            next_least_sig_val = pvals.nlargest(count+2)[-1]
            print("############################################################\n")
            print(f"Caught a LinAlgError: singular matrix. Removing {next_least_sig_feature}: {next_least_sig_val}.\n")
            remaining.remove(next_least_sig_feature)
            count += 1
            if verbose is True:
                print(remaining)
                print("\n")
            continue


        # Step 3: identify least significant (highest p-value) feature
        count = 0
        pvals = init_model.pvalues
        pvals = pvals.drop([f"{groups} Var", "Intercept"])
        least_sig_feature = pvals.idxmax()
        least_sig_val = pvals.max()
        
        if verbose is True:
            print(init_formula)
            print(f"{least_sig_feature}: {least_sig_val}")
            print("\n")

        # Step 4: ID if least significant feature exceeds significance level
        if least_sig_val > sig_level:
            # Step 5: Remove least significant feature from the set
            remaining.remove(least_sig_feature)
            continue

        if least_sig_val < sig_level:
            # Step 6: 
            # if all p-values are better than sig level, select that model
            if len(remaining) == 0:
                return print("No feature meets the selection criterion.")

            model = smf.mixedlm(init_formula, data, groups=groups).fit(reml=False)
            break

    return model

# %%
# model = mlm_backward_step(prelockdownData, "Natural", acoustic_vars, "LocationID", sig_level = 0.05, verbose=True)
# print(model.model.formula)
# print(model.summary())
# print("Adjusted R-squared: ",adjusted_r_squared(model, prelockdownData))

# %% [markdown]
# This results in a drastically cut down feature set, which is good, but it's still a very complex model, resulting in a low adjusted r-squared value. We've identified all of the potentially significant features, but we still need to do further feature selection. For this, we move onto forward step feature selection with the Akaike Information Criterion as our criterion.
#
# ### Forward Step Feature selection
# https://planspace.org/20150423-forward_selection_with_statsmodels/
#
# In forward step selection, we build a model for each potential feature individually, calculate the best performing model, and select that feature. We then add every other feature to it and build n-1 two-feature models, then calculate the best performing model and select those two features. This continues until adding features to the model no longer improves its criterion performance.
#
# It is important in this method to use a criterion which punishes model complexity, otherwise the model will always improve by adding new features.

# %%
def mlm_step_forward(data, response, features, groups, criterion = "aic", verbose=False):
    data = data[[response, groups] + features] # Cut down the dataset to just what is required

    if criterion in ["bic", "aic"]:
        direction = "minimise"
    elif criterion in ["r_squared", "adjusted_r_squared"]:
        direction = "maximise"
    else:
        raise ValueError(f"Criterion type not recognised")

    remaining = features.copy()  # Avoid overwriting initial features list
    selected = []
    if direction == "minimise":
        current_score, best_new_score = 10000.0, 10000.0
    if direction == "maximise":
        current_score, best_new_score = 0.0, 0.0

    while remaining and current_score == best_new_score:
        scores_with_candidates = []
        for candidate in remaining:
            formula = "{} ~ {}".format(response, ' + '.join(selected + [candidate]))
            # if verbose is True:
            #     print(formula)

            try:
                model_fit = smf.mixedlm(formula, data, groups=groups).fit(reml=False)

            except LinAlgError as error:
                # Sometimes a singular matrix error is raised when fitting the model. 
                print("############################################################\n")
                print(formula)
                print(f"Caught a LinAlgError: singular matrix. Skipping {candidate}.\n")
                continue

            if criterion == "bic":
                score = model_fit.bic
            if criterion == "aic":
                score = model_fit.aic
            if criterion == "r_squared":
                score = r_squared(model_fit, data)
            if criterion == "adjusted_r_squared":
                score = adjusted_r_squared(model_fit, data)
            
            scores_with_candidates.append((score, candidate))

        scores_with_candidates.sort()
        if verbose is True:
            print("scores_with_candidates: ", scores_with_candidates)

        if direction == "minimise":
            best_new_score, best_candidate = scores_with_candidates.pop(0)
            if current_score > best_new_score:
                remaining.remove(best_candidate)
                selected.append(best_candidate)
                current_score = best_new_score
        if direction == "maximise":
            best_new_score, best_candidate = scores_with_candidates.pop()
            if current_score < best_new_score:
                remaining.remove(best_candidate)
                selected.append(best_candidate)
                current_score = best_new_score

        if verbose is True:
            print("selected: ", selected)
            print("\n")


    formula = "{} ~ {}".format(response, ' + '.join(selected))
    model_fit = smf.mixedlm(formula, data, groups=groups).fit(reml=False)
    return model_fit

# %%
# selected_features = list(model.fe_params.index[1:])

# Natural_model = mlm_step_forward(prelockdownData, "Natural", selected_features, "LocationID", criterion="aic", verbose=True)
# print(Natural_model.model.formula)
# print(Natural_model.summary())
# print("AIC: ", Natural_model.aic)
# print("Adjusted R-squared: ", adjusted_r_squared(Natural_model, prelockdownData))
# print(Natural_model.random_effects)

# %% [markdown]
# Success! We can see that this method has reduced the features even further. However, I suspect there are some issues with multicollinearity, so we'll tackle that next.

# %% [markdown]
# #### Reducing multi-collinearity
# We've identified multi-collinearity among several of the features which were selected by the backward-forward feature selection. This is identified through the Variance Inflation Factor (VIF). We've set the max acceptable VIF at a fairly high level of 10 to be very lenient to our potential features. To address this, we remove the highest VIF feature and re-build the model, then check the VIF again. We do this until the max VIF feature is below our set criterion.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

def run_vif(model, data):
    features = list(model.fe_params.index[1:])
    X = data[features].dropna()
    X = add_constant(X)
    return pd.Series([variance_inflation_factor(X.values, i) 
                for i in range(X.shape[1])], 
                index=X.columns)

def vif_reduction(model, data, response, groups, max_vif = 10):
    # VIF Reduction
    vif = run_vif(model, data)
    if vif.max() > max_vif:
        print(f"\nWARNING: VIF of some features exceeds stated max VIF ({max_vif}).")
        print(vif)
    else:
        print("No VIF issues identified.")
        return model, vif

    while vif.max() > max_vif:
        print(f"\nRemoving {vif.idxmax()}: {vif.max()}")

        cutdown_features = list(model.fe_params.index[1:])
        cutdown_features.remove(vif.idxmax())
        formula = "{} ~ {}".format(response, ' + '.join(cutdown_features))
        print(formula)
        model = smf.mixedlm(formula, data, groups=groups).fit(reml=False)
        vif = run_vif(model, data)

    return model, vif

# %%
# Natural_model, Natural_vif = vif_reduction(Natural_model, prelockdownData, "Natural", "LocationID", max_vif = 10)
# print(Natural_model.model.formula)
# print(Natural_model.summary())
# print("AIC: ", Natural_model.aic)
# print("Adjusted R-squared: ", adjusted_r_squared(Natural_model, prelockdownData))
# print(Natural_model.random_effects)

# %%
# plt.scatter(Natural_model.fittedvalues - Natural_model.resid, Natural_model.resid, alpha=0.5)
# plt.title("Residual vs. Fitted for Natural model")
# plt.xlabel("Fitted values")
# plt.ylabel("Residuals")
# plt.show()

# %%
# plt.scatter(Natural_model.fittedvalues, prelockdownData["Natural"], alpha=0.5)
# plt.title("Actual vs. Fitted for Natural model")
# plt.xlabel("Fitted values")
# plt.ylabel("Actual values")
# plt.show()

# %% [markdown]
# ## Model building function
#
# Now that we've worked out the method, let's wrap it all up into a function so we can repeat this easily

# %%
def mlm_model_building(data, response, features, groups, backward_selection=True, sig_level=0.05, criterion="bic", check_vif = True, max_vif = 10, verbose=False):
    if backward_selection is True:
        print("Running Backward step feature selection.")
        back_model = mlm_backward_step(data, response, features, groups, sig_level, verbose)
        back_features = list(back_model.fe_params.index[1:])
        print("Selected features: ", back_features)
        print(back_model.summary())
        print("Adj R-sq: ", adjusted_r_squared(back_model, data))
        print("AIC:      ", back_model.aic)
        print("BIC:      ", back_model.bic)
        print("\n##################################################")
    else:
        init_formula = "{} ~ {}".format(response, ' + '.join(remaining))
        back_model = smf.mixedlm(init_formula, data, groups = groups).fit(reml=False)
        back_features = list(back_model.fe_params.index[1:])

    print("Running Forward step feature selection.")
    forward_model = mlm_step_forward(data, response, back_features, groups, criterion, verbose)
    forward_features = list(forward_model.fe_params.index[1:])
    print(forward_model.model.formula)
    print(forward_model.summary())
    print("Adj R-sq: ", adjusted_r_squared(forward_model, data))
    print("AIC:      ", forward_model.aic)
    print("BIC:      ", forward_model.bic)
    print(forward_model.random_effects)

    if check_vif is True:
        # VIF Reduction
        print("\n##################################################")
        final_model, vif = vif_reduction(forward_model, data, response, groups, max_vif)

        print(final_model.model.formula)
        print(final_model.summary())
        print("Adj R-sq: ", adjusted_r_squared(final_model, data))
        print("AIC:      ", final_model.aic)
        print("BIC:      ", final_model.bic)
        print(final_model.random_effects)
    else:
        final_model = forward_model
        vif = run_vif(final_model, data)


    return final_model, back_model, forward_model, vif

# %% [markdown]
# ## `overall` Model

# %%
overall_model, overall_back, overall_forward, overall_vif = mlm_model_building(prelockdownData, "overall", acoustic_vars, "LocationID", criterion="aic", verbose=False)
# Out:
# Running Backward step feature selection.
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing THD_5_THD_95: 0.19022310568379996.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_I_50: 0.17947017320569647.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_N_10: 0.17391206709211005.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_T_95: 0.1726311861541241.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing N_10: 0.16375305823943698.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_FS_50: 0.16254849079232092.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LAeq_10_LAeq_90: 0.15788305459759056.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing T_95: 0.20359889129980224.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_T_10: 0.20047157222714485.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_SIL_10: 0.19617511747261218.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing I_50: 0.6444950520378374.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_T_5: 0.4843698113466983.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_MaxFreq: 0.35282632677572545.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_T_Max: 0.25667412746684704.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_LCeq_Min: 0.25046216993231274.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LCeq_Min: 0.2474352633638689.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_I: 0.22563472415589003.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_LZeq: 0.19901874324088398.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_PeakMaxFreq: 0.13847901742919197.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_PeakSpectralCentroid: 0.12228796646732255.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LZeq_50: 0.11464127110598338.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_R_5: 0.11244417330882776.
#
# Selected features:  ['log_FS_5', 'log_FS_Max', 'LAeq', 'log_LAeq', 'sq_LAeq', 'log_LAeq_5', 'sq_LAeq_5', 'LAeq_50', 'LAeq_95', 'LAeq_5_LAeq_95', 'N_5', 'log_N_5', 'sq_N_5', 'sq_N_10', 'sq_N_Min', 'N_Max', 'N_Max_N_Min', 'sq_R_90', 'sq_R_Min', 'S', 'log_S', 'sq_S', 'S_10', 'sq_S_10', 'S_50', 'log_S_50', 'sq_S_50', 'log_S_90', 'S_10_S_90', 'log_SIL_50', 'SIL_Min', 'log_SIL_Min', 'sq_SIL_Min', 'T_50', 'log_T_50', 'sq_T_50', 'LCeq_95', 'log_LCeq_95', 'sq_LCeq_95', 'LZeq_95', 'log_LZeq_95', 'sq_LZeq_95', 'LZeq_Min', 'log_LZeq_Min', 'sq_LZeq_Min']
#              Mixed Linear Model Regression Results
# ===============================================================
# Model:                MixedLM   Dependent Variable:   overall
# No. Observations:     644       Method:               ML
# No. Groups:           13        Scale:                0.4789
# Min. group size:      11        Log-Likelihood:       -686.0926
# Max. group size:      81        Converged:            Yes
# Mean group size:      49.5
# ---------------------------------------------------------------
#                 Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# ---------------------------------------------------------------
# Intercept         4.042    0.106 38.288 0.000    3.835    4.249
# log_FS_5         -0.319    0.126 -2.536 0.011   -0.566   -0.073
# log_FS_Max        0.290    0.125  2.323 0.020    0.045    0.535
# LAeq           -187.285   51.157 -3.661 0.000 -287.551  -87.019
# log_LAeq         93.053   25.790  3.608 0.000   42.506  143.600
# sq_LAeq          94.821   25.587  3.706 0.000   44.671  144.970
# log_LAeq_5      -68.947   19.002 -3.628 0.000 -106.191  -31.704
# sq_LAeq_5       -67.509   18.844 -3.582 0.000 -104.443  -30.575
# LAeq_50           3.068    0.790  3.886 0.000    1.521    4.616
# LAeq_95         126.898   35.143  3.611 0.000   58.018  195.777
# LAeq_5_LAeq_95   72.412   20.020  3.617 0.000   33.174  111.651
# N_5              -3.467    1.240 -2.796 0.005   -5.898   -1.037
# log_N_5           2.272    0.950  2.391 0.017    0.410    4.135
# sq_N_5            1.957    0.518  3.780 0.000    0.943    2.972
# sq_N_10          -0.917    0.265 -3.456 0.001   -1.437   -0.397
# sq_N_Min          3.296    0.829  3.975 0.000    1.671    4.921
# N_Max            -7.809    2.695 -2.898 0.004  -13.091   -2.527
# N_Max_N_Min       5.891    2.045  2.881 0.004    1.883    9.899
# sq_R_90          -1.135    0.379 -2.994 0.003   -1.877   -0.392
# sq_R_Min          0.519    0.153  3.381 0.001    0.218    0.820
# S                72.771   29.775  2.444 0.015   14.414  131.129
# log_S           -36.810   15.226 -2.418 0.016  -66.652   -6.967
# sq_S            -44.303   16.256 -2.725 0.006  -76.164  -12.442
# S_10              4.321    1.606  2.691 0.007    1.173    7.468
# sq_S_10           2.274    0.894  2.542 0.011    0.521    4.026
# S_50            -71.431   29.466 -2.424 0.015 -129.182  -13.679
# log_S_50         38.180   15.304  2.495 0.013    8.185   68.175
# sq_S_50          39.358   15.722  2.503 0.012    8.543   70.173
# log_S_90         -3.504    1.484 -2.361 0.018   -6.412   -0.595
# S_10_S_90        -2.880    0.867 -3.322 0.001   -4.579   -1.180
# log_SIL_50       -3.256    0.770 -4.230 0.000   -4.765   -1.748
# SIL_Min          76.131   23.998  3.172 0.002   29.095  123.166
# log_SIL_Min     -35.653   12.112 -2.944 0.003  -59.393  -11.913
# sq_SIL_Min      -40.490   12.073 -3.354 0.001  -64.152  -16.829
# T_50              0.888    0.241  3.687 0.000    0.416    1.360
# log_T_50         -0.379    0.140 -2.714 0.007   -0.654   -0.105
# sq_T_50          -0.712    0.164 -4.342 0.000   -1.034   -0.391
# LCeq_95         236.059   77.994  3.027 0.002   83.194  388.924
# log_LCeq_95    -121.534   40.264 -3.018 0.003 -200.451  -42.617
# sq_LCeq_95     -116.473   38.281 -3.043 0.002 -191.503  -41.442
# LZeq_95        -416.779  108.691 -3.835 0.000 -629.810 -203.748
# log_LZeq_95     210.005   54.898  3.825 0.000  102.407  317.604
# sq_LZeq_95      208.319   54.353  3.833 0.000  101.789  314.849
# LZeq_Min        249.695   79.806  3.129 0.002   93.278  406.111
# log_LZeq_Min   -124.627   41.130 -3.030 0.002 -205.240  -44.014
# sq_LZeq_Min    -125.362   39.108 -3.205 0.001 -202.013  -48.711
# LocationID Var    0.034    0.038
# ===============================================================
#
# Adj R-sq:  0.38757064402428487
# AIC:       1468.1852665534643
# BIC:       1682.6348054064733
#
# ##################################################
# Running Forward step feature selection.
# overall ~ log_LCeq_95 + sq_T_50 + sq_LZeq_Min
#           Mixed Linear Model Regression Results
# =========================================================
# Model:              MixedLM Dependent Variable: overall
# No. Observations:   644     Method:             ML
# No. Groups:         13      Scale:              0.5533
# Min. group size:    11      Log-Likelihood:     -739.8307
# Max. group size:    81      Converged:          Yes
# Mean group size:    49.5
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       3.771    0.115 32.898 0.000  3.546  3.995
# log_LCeq_95    -0.639    0.244 -2.622 0.009 -1.117 -0.161
# sq_T_50        -0.058    0.029 -2.004 0.045 -0.115 -0.001
# sq_LZeq_Min     0.351    0.211  1.660 0.097 -0.063  0.766
# LocationID Var  0.146    0.087
# =========================================================
#
# Adj R-sq:  0.3415551818278192
# AIC:       1491.6613305053488
# BIC:       1518.4675228619749
# {'CamdenTown': LocationID   -0.490415
# dtype: float64, 'EustonTap': LocationID   -0.640527
# dtype: float64, 'MarchmontGarden': LocationID   -0.287732
# dtype: float64, 'MonumentoGaribaldi': LocationID    0.072986
# dtype: float64, 'PancrasLock': LocationID   -0.161364
# dtype: float64, 'RegentsParkFields': LocationID    0.283675
# dtype: float64, 'RegentsParkJapan': LocationID    0.644386
# dtype: float64, 'RussellSq': LocationID    0.453453
# dtype: float64, 'SanMarco': LocationID    0.160778
# dtype: float64, 'StPaulsCross': LocationID    0.139976
# dtype: float64, 'StPaulsRow': LocationID   -0.0026
# dtype: float64, 'TateModern': LocationID    0.232676
# dtype: float64, 'TorringtonSq': LocationID   -0.405291
# dtype: float64}
#
# ##################################################
#
# WARNING: VIF of some features exceeds stated max VIF (10).
# const           1.467722
# log_LCeq_95    26.319910
# sq_T_50         1.146595
# sq_LZeq_Min    26.628475
# dtype: float64
#
# Removing sq_LZeq_Min: 26.628475306553966
# overall ~ log_LCeq_95 + sq_T_50
# overall ~ log_LCeq_95 + sq_T_50
#           Mixed Linear Model Regression Results
# =========================================================
# Model:              MixedLM Dependent Variable: overall
# No. Observations:   644     Method:             ML
# No. Groups:         13      Scale:              0.5553
# Min. group size:    11      Log-Likelihood:     -741.2043
# Max. group size:    81      Converged:          Yes
# Mean group size:    49.5
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       3.734    0.114 32.708 0.000  3.511  3.958
# log_LCeq_95    -0.251    0.071 -3.556 0.000 -0.390 -0.113
# sq_T_50        -0.052    0.029 -1.810 0.070 -0.109  0.004
# LocationID Var  0.151    0.090
# =========================================================
#
# Adj R-sq:  0.34015367835998556
# AIC:       1492.4086214958515
# BIC:       1514.7471151263733
# {'CamdenTown': LocationID   -0.471238
# dtype: float64, 'EustonTap': LocationID   -0.652732
# dtype: float64, 'MarchmontGarden': LocationID   -0.235179
# dtype: float64, 'MonumentoGaribaldi': LocationID    0.081857
# dtype: float64, 'PancrasLock': LocationID   -0.131184
# dtype: float64, 'RegentsParkFields': LocationID    0.33318
# dtype: float64, 'RegentsParkJapan': LocationID    0.665039
# dtype: float64, 'RussellSq': LocationID    0.456111
# dtype: float64, 'SanMarco': LocationID    0.098734
# dtype: float64, 'StPaulsCross': LocationID    0.096952
# dtype: float64, 'StPaulsRow': LocationID    0.012663
# dtype: float64, 'TateModern': LocationID    0.227368
# dtype: float64, 'TorringtonSq': LocationID   -0.481571
# dtype: float64}

# %%
plt.scatter(overall_model.fittedvalues - overall_model.resid, overall_model.resid, alpha=0.5)
plt.title("Residual vs. Fitted for overall model")
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.show()

# %%
plt.scatter(overall_model.fittedvalues, prelockdownData["overall"], alpha=0.5)
plt.title("Actual vs. Fitted for overall model")
plt.xlabel("Fitted values")
plt.ylabel("Actual values")
plt.show()

# %% [markdown]
# ## `Natural` model

# %%
Natural_model, Natural_back, Natural_foward, Natural_vif = mlm_model_building(prelockdownData, "Natural", acoustic_vars, "LocationID", criterion="aic", check_vif = True, max_vif = 10, verbose=False)
# Out:
# Running Backward step feature selection.
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing THD_Min: 0.27191684412348816.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_LAeq_10: 0.2636175734859417.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing T_5: 0.25440976321423336.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LZeq_10: 0.21578995570055737.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_S_10: 0.19539607420142158.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_R_10: 0.19217996377569613.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_T_5: 0.19109864891322392.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LAeq_Max: 0.177466371171782.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_LZeq_95: 0.17384654863170768.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LAeq_10: 0.17359703632267076.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_SIL_Max: 0.17210224227019033.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_LZeq_90: 0.1702488426740727.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_FS: 0.16259582948980555.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing SIL_50: 0.15695044383004358.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_SIL_5: 0.15506581259521837.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_SIL_50: 0.15377829583624067.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LZeq_5_LZeq_95: 0.1480805571794696.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LZeq_10_LZeq_90: 0.14635755705527886.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LZeq_5: 0.14136488145470968.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_SIL_50: 0.1410454383576421.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing S_10: 0.13737486899464948.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_LZeq_90: 0.1278890655820727.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_LZeq_95: 0.1266807618113101.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing THD_5_THD_95: 0.12062942126854753.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing SIL_5: 0.1154256229881593.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing THD_10: 0.10611787309128465.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_FS_5: 0.10475270926207154.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_S_Min: 0.09072363686703756.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_R: 0.08797760915744517.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_SIL_5: 0.0863068225572705.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LZeq_50: 0.08465571024504322.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_FS_Min: 0.08437271400236634.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_PeakSpectralCentroid: 0.08352014910758032.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing T_Max: 0.08195306187652583.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_LZeq_5: 0.08092620862811627.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_LZeq_50: 0.08035580361829239.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing PeakSpectralCentroid: 0.07656834105825089.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LZeq_Max_LZeq_Min: 0.07491359428634282.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_LAeq_5_LAeq_95: 0.06942753638256588.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_R_5: 0.06424438208451538.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_N_10: 0.06175111167951836.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_R_Max: 0.05797308198487948.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_S_10: 0.05673163776637092.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing R_10: 0.05591083567481864.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_N_Max: 0.05208245893499499.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_LCeq_10: 0.047941317016566384.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_LZeq_10: 0.047936834987591735.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_I_5: 0.047173003390114536.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_S_5: 0.045750672679657316.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_MaxFreq: 0.044720030437471185.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_LCeq_90: 0.04078680911219165.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_LZeq_Min: 0.04055379838818373.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LCeq_10_LCeq_90: 0.03918566789613603.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LZeq_Min: 0.03891969920055875.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_LCeq_90: 0.038789180619515126.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_SIL_90: 0.03724254443773538.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing FS_Max_FS_Min: 0.03697842796756542.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing S_95: 0.036755090165702.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_LZeq_Min: 0.03634793949149547.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing SIL_90: 0.03488666592994325.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing MaxFreq: 0.8782788970050266.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_SIL_10: 0.8604770427972591.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_LCeq_10: 0.8277509844481801.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_FS_5: 0.8089926598739804.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing SIL_10: 0.8006387635810609.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_LAeq_95: 0.779581158458806.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_SIL_10: 0.750865932827336.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing N_Max: 0.6404481582494739.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_FS_Max: 0.5032070236280838.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_LAeq_90: 0.47130927656395627.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_LZeq_10: 0.46708699719775026.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LAeq_95: 0.436296598295957.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_N_Max: 0.43296461705252687.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LAeq_90: 0.43203297386617256.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_SIL_95: 0.41126510240298075.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_LAeq_90: 0.3960306906771982.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_N_5: 0.35263090309113077.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing SIL_95: 0.2697934786832895.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_MaxFreq: 0.25178327326098804.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_SIL_95: 0.22003111657907515.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing FS_10_FS_90: 0.2094480712237059.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_SIL_90: 0.6268562530606189.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LCeq_Max_LCeq_Min: 0.6264790642175052.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_LAeq: 0.6185275030422521.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LCeq_Min: 0.6168026658880721.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LAeq_5_LAeq_95: 0.6050383860512394.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_LCeq_Max: 0.5830844523558978.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing SpectralCentroid: 0.506297628128731.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_SpectralCentroid: 0.47249873900162853.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_LAeq: 0.3248720085702598.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_S_5: 0.19743118749739552.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing S_90: 0.19547879890207298.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LAeq: 0.19022784327327136.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_FS_90: 0.14959666873984384.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_FS_50: 0.2460153070805059.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_I_Min: 0.16923231423416552.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_LCeq: 0.16876557093889344.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_T_Max: 0.14654907823462973.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_LAeq_50: 0.10969546048272835.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_I_90: 0.10014423062829127.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing sq_T_95: 0.09618251925461861.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing I_Max: 0.09511202736089817.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_R_95: 0.0576390928848249.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing T_95: 0.05648390922564502.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing R_5: 0.052618328957462455.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing R_5_R_95: 0.052443522222433384.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_R_90: 0.04428894734047346.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_LCeq: 0.04173586285580528.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing log_I: 0.04012775800001596.
#
# ############################################################
#
# Caught a LinAlgError: singular matrix. Removing LAeq_50: 0.03805486399748025.
#
# Selected features:  ['N_10', 'log_N_90', 'sq_N_90', 'N_95', 'log_N_95', 'sq_N_95', 'N_10_N_90', 'R_50', 'R_90', 'R_Min', 'log_R_Min', 'sq_R_Min', 'S', 'log_S', 'sq_S', 'S_Min', 'sq_S_Min', 'log_T_50', 'log_T_95', 'LCeq']
#            Mixed Linear Model Regression Results
# ===========================================================
# Model:              MixedLM  Dependent Variable:  Natural
# No. Observations:   644      Method:              ML
# No. Groups:         13       Scale:               0.6728
# Min. group size:    11       Log-Likelihood:      -792.6564
# Max. group size:    81       Converged:           Yes
# Mean group size:    49.5
# -----------------------------------------------------------
#                 Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# -----------------------------------------------------------
# Intercept        2.685    0.093 28.772 0.000   2.502  2.868
# N_10            30.224   11.036  2.739 0.006   8.593 51.854
# log_N_90       -18.121    6.008 -3.016 0.003 -29.895 -6.346
# sq_N_90         -7.118    2.940 -2.421 0.015 -12.881 -1.356
# N_95           -21.901    7.877 -2.780 0.005 -37.340 -6.461
# log_N_95        19.469    6.194  3.143 0.002   7.329 31.610
# sq_N_95          7.646    3.096  2.470 0.014   1.579 13.713
# N_10_N_90      -15.370    5.610 -2.740 0.006 -26.365 -4.374
# R_50             0.829    0.272  3.047 0.002   0.296  1.362
# R_90            -1.199    0.390 -3.070 0.002  -1.964 -0.433
# R_Min           -8.373    2.709 -3.091 0.002 -13.683 -3.064
# log_R_Min        3.176    1.109  2.864 0.004   1.002  5.350
# sq_R_Min         7.481    2.370  3.157 0.002   2.836 12.126
# S                6.826    2.635  2.591 0.010   1.662 11.990
# log_S           -3.553    1.569 -2.264 0.024  -6.629 -0.477
# sq_S            -3.696    1.216 -3.040 0.002  -6.079 -1.313
# S_Min           -1.070    0.530 -2.017 0.044  -2.109 -0.030
# sq_S_Min         1.388    0.475  2.924 0.003   0.458  2.319
# log_T_50         0.269    0.096  2.802 0.005   0.081  0.458
# log_T_95        -0.232    0.085 -2.719 0.007  -0.400 -0.065
# LCeq            -0.480    0.122 -3.945 0.000  -0.718 -0.242
# LocationID Var   0.024    0.026
# ===========================================================
#
# Adj R-sq:  0.4351442633268686
# AIC:       1631.3128713294045
# BIC:       1734.0699420298047
#
# ##################################################
# Running Forward step feature selection.
# Natural ~ LCeq + sq_S_Min + log_R_Min + R_50 + R_90 + sq_S + log_T_95 + log_T_50 + N_95
#           Mixed Linear Model Regression Results
# =========================================================
# Model:              MixedLM Dependent Variable: Natural
# No. Observations:   644     Method:             ML
# No. Groups:         13      Scale:              0.6893
# Min. group size:    11      Log-Likelihood:     -806.5683
# Max. group size:    81      Converged:          No
# Mean group size:    49.5
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       2.501    0.093 26.774 0.000  2.318  2.684
# LCeq           -0.413    0.095 -4.367 0.000 -0.598 -0.228
# sq_S_Min        0.463    0.146  3.180 0.001  0.178  0.748
# log_R_Min      -0.108    0.085 -1.275 0.202 -0.275  0.058
# R_50            0.841    0.242  3.477 0.001  0.367  1.314
# R_90           -1.093    0.374 -2.923 0.003 -1.827 -0.360
# sq_S           -0.319    0.125 -2.547 0.011 -0.565 -0.074
# log_T_95       -0.252    0.086 -2.919 0.004 -0.420 -0.083
# log_T_50        0.216    0.094  2.308 0.021  0.033  0.399
# N_95            0.264    0.157  1.677 0.094 -0.045  0.572
# LocationID Var  0.089    0.082
# =========================================================
#
# Adj R-sq:  0.4322627307244754
# AIC:       1637.136665658325
# BIC:       1690.7490503715771
# {'CamdenTown': LocationID   -0.349295
# dtype: float64, 'EustonTap': LocationID   -0.363887
# dtype: float64, 'MarchmontGarden': LocationID    0.039292
# dtype: float64, 'MonumentoGaribaldi': LocationID   -0.046798
# dtype: float64, 'PancrasLock': LocationID    0.042849
# dtype: float64, 'RegentsParkFields': LocationID    0.247209
# dtype: float64, 'RegentsParkJapan': LocationID    0.358704
# dtype: float64, 'RussellSq': LocationID    0.256274
# dtype: float64, 'SanMarco': LocationID    0.149784
# dtype: float64, 'StPaulsCross': LocationID   -0.093515
# dtype: float64, 'StPaulsRow': LocationID   -0.294794
# dtype: float64, 'TateModern': LocationID    0.317972
# dtype: float64, 'TorringtonSq': LocationID   -0.263796
# dtype: float64}
#
# ##################################################
#
# WARNING: VIF of some features exceeds stated max VIF (10).
# const         1.258955
# LCeq          4.907126
# sq_S_Min     14.476971
# log_R_Min     5.131775
# R_50         24.553799
# R_90         45.686257
# sq_S         11.797233
# log_T_95      6.521792
# log_T_50      7.020193
# N_95         18.303995
# dtype: float64
#
# Removing R_90: 45.68625655623018
# Natural ~ LCeq + sq_S_Min + log_R_Min + R_50 + sq_S + log_T_95 + log_T_50 + N_95
#
# Removing N_95: 14.810191044356868
# Natural ~ LCeq + sq_S_Min + log_R_Min + R_50 + sq_S + log_T_95 + log_T_50
#
# Removing sq_S_Min: 11.536580912947999
# Natural ~ LCeq + log_R_Min + R_50 + sq_S + log_T_95 + log_T_50
# Natural ~ LCeq + log_R_Min + R_50 + sq_S + log_T_95 + log_T_50
#           Mixed Linear Model Regression Results
# =========================================================
# Model:              MixedLM Dependent Variable: Natural
# No. Observations:   644     Method:             ML
# No. Groups:         13      Scale:              0.7052
# Min. group size:    11      Log-Likelihood:     -817.4064
# Max. group size:    81      Converged:          Yes
# Mean group size:    49.5
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       2.497    0.121 20.609 0.000  2.259  2.734
# LCeq           -0.387    0.093 -4.169 0.000 -0.570 -0.205
# log_R_Min      -0.183    0.075 -2.451 0.014 -0.330 -0.037
# R_50            0.194    0.101  1.921 0.055 -0.004  0.393
# sq_S            0.152    0.052  2.901 0.004  0.049  0.255
# log_T_95       -0.258    0.085 -3.039 0.002 -0.425 -0.092
# log_T_50        0.169    0.089  1.888 0.059 -0.006  0.344
# LocationID Var  0.169    0.098
# =========================================================
#
# Adj R-sq:  0.4244548167230793
# AIC:       1652.812748361459
# BIC:       1693.022036896398
# {'CamdenTown': LocationID   -0.591837
# dtype: float64, 'EustonTap': LocationID   -0.384187
# dtype: float64, 'MarchmontGarden': LocationID    0.035869
# dtype: float64, 'MonumentoGaribaldi': LocationID   -0.028245
# dtype: float64, 'PancrasLock': LocationID    0.044037
# dtype: float64, 'RegentsParkFields': LocationID    0.264958
# dtype: float64, 'RegentsParkJapan': LocationID    0.665571
# dtype: float64, 'RussellSq': LocationID    0.664022
# dtype: float64, 'SanMarco': LocationID    0.063235
# dtype: float64, 'StPaulsCross': LocationID   -0.173899
# dtype: float64, 'StPaulsRow': LocationID   -0.489529
# dtype: float64, 'TateModern': LocationID    0.325814
# dtype: float64, 'TorringtonSq': LocationID   -0.395809
# dtype: float64}

# %%
plt.scatter(Natural_model.fittedvalues - Natural_model.resid, Natural_model.resid, alpha=0.5)
plt.title("Residual vs. Fitted for Natural model")
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.show()

# %%
plt.scatter(Natural_model.fittedvalues, prelockdownData["Natural"], alpha=0.5)
plt.title("Actual vs. Fitted for Natural model")
plt.xlabel("Fitted values")
plt.ylabel("Actual values")
plt.show()

# %% [markdown]
# ## `Traffic` model

# %%
Traffic_model, Traffic_back, Traffic_foward, Traffic_vif = mlm_model_building(prelockdownData, "Traffic", acoustic_vars, "LocationID", criterion="aic", check_vif = True, max_vif = 10, verbose=False)
# Out:
# Running Backward step feature selection.
# Selected features:  ['FS_90', 'log_FS_90', 'log_FS_Min', 'LAeq_95', 'log_N_90', 'log_N_95', 'sq_S_Min', 'log_S_Max', 'sq_S_Max', 'S_Max_S_Min', 'log_SIL_90', 'log_T_95', 'sq_T_95', 'log_I_5', 'sq_I_5', 'I_90', 'log_I_Min', 'sq_I_Min', 'I_Max', 'sq_I_5_I_95', 'I_Max_I_Min', 'LCeq', 'sq_LCeq', 'LCeq_90', 'sq_LCeq_90', 'LCeq_Max', 'log_LCeq_Max', 'sq_LCeq_Max', 'log_LZeq_5', 'log_LZeq_95', 'LZeq_5_LZeq_95', 'THD_50']
#            Mixed Linear Model Regression Results
# ============================================================
# Model:               MixedLM  Dependent Variable:  Traffic
# No. Observations:    644      Method:              ML
# No. Groups:          13       Scale:               0.5773
# Min. group size:     11       Log-Likelihood:      -757.2033
# Max. group size:     81       Converged:           Yes
# Mean group size:     49.5
# ------------------------------------------------------------
#                 Coef.  Std.Err.   z    P>|z|  [0.025  0.975]
# ------------------------------------------------------------
# Intercept        2.536    0.163 15.577 0.000   2.217   2.855
# FS_90           -0.171    0.076 -2.267 0.023  -0.319  -0.023
# log_FS_90        0.622    0.141  4.403 0.000   0.345   0.899
# log_FS_Min      -0.332    0.121 -2.754 0.006  -0.569  -0.096
# LAeq_95         -1.924    0.654 -2.939 0.003  -3.206  -0.641
# log_N_90        -5.362    1.798 -2.983 0.003  -8.886  -1.839
# log_N_95         5.361    1.581  3.392 0.001   2.263   8.459
# sq_S_Min         0.852    0.283  3.010 0.003   0.297   1.406
# log_S_Max       -1.389    0.376 -3.694 0.000  -2.126  -0.652
# sq_S_Max        -1.159    0.258 -4.491 0.000  -1.666  -0.653
# S_Max_S_Min      2.218    0.512  4.335 0.000   1.215   3.221
# log_SIL_90       2.617    0.765  3.421 0.001   1.118   4.117
# log_T_95        -0.195    0.065 -3.029 0.002  -0.322  -0.069
# sq_T_95          0.073    0.026  2.788 0.005   0.022   0.125
# log_I_5         -0.698    0.173 -4.038 0.000  -1.036  -0.359
# sq_I_5           2.758    0.643  4.290 0.000   1.498   4.017
# I_90            -0.344    0.118 -2.905 0.004  -0.576  -0.112
# log_I_Min       -1.331    0.584 -2.280 0.023  -2.476  -0.187
# sq_I_Min        -2.235    0.730 -3.063 0.002  -3.665  -0.805
# I_Max           40.640   14.435  2.815 0.005  12.349  68.931
# sq_I_5_I_95     -2.017    0.497 -4.058 0.000  -2.991  -1.043
# I_Max_I_Min    -40.212   14.283 -2.815 0.005 -68.206 -12.218
# LCeq           -11.057    3.032 -3.647 0.000 -16.998  -5.115
# sq_LCeq         10.878    2.939  3.701 0.000   5.117  16.640
# LCeq_90          7.300    2.868  2.546 0.011   1.680  12.921
# sq_LCeq_90      -6.430    2.681 -2.398 0.016 -11.684  -1.175
# LCeq_Max        40.762   15.207  2.680 0.007  10.956  70.568
# log_LCeq_Max   -20.312    7.558 -2.688 0.007 -35.125  -5.499
# sq_LCeq_Max    -20.671    7.749 -2.667 0.008 -35.859  -5.482
# log_LZeq_5       5.516    1.645  3.353 0.001   2.291   8.740
# log_LZeq_95     -5.390    1.440 -3.744 0.000  -8.211  -2.568
# LZeq_5_LZeq_95  -3.550    1.101 -3.224 0.001  -5.708  -1.392
# THD_50          -0.174    0.062 -2.802 0.005  -0.296  -0.052
# LocationID Var   0.278    0.171
# ============================================================
#
# Adj R-sq:  0.4329369997609861
# AIC:       1584.406687636484
# BIC:       1740.7761430501364
#
# ##################################################
# Running Forward step feature selection.
# Traffic ~ THD_50 + sq_S_Min + log_SIL_90 + log_I_Min + sq_T_95 + log_T_95 + log_FS_90 + log_FS_Min + FS_90
#           Mixed Linear Model Regression Results
# =========================================================
# Model:              MixedLM Dependent Variable: Traffic
# No. Observations:   644     Method:             ML
# No. Groups:         13      Scale:              0.6459
# Min. group size:    11      Log-Likelihood:     -793.8653
# Max. group size:    81      Converged:          Yes
# Mean group size:    49.5
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       2.544    0.170 14.931 0.000  2.210  2.878
# THD_50         -0.156    0.050 -3.115 0.002 -0.253 -0.058
# sq_S_Min       -0.301    0.082 -3.662 0.000 -0.463 -0.140
# log_SIL_90      0.326    0.121  2.688 0.007  0.088  0.564
# log_I_Min       0.046    0.038  1.211 0.226 -0.029  0.121
# sq_T_95         0.076    0.027  2.780 0.005  0.022  0.129
# log_T_95       -0.169    0.060 -2.822 0.005 -0.287 -0.052
# log_FS_90       0.515    0.129  3.986 0.000  0.262  0.768
# log_FS_Min     -0.349    0.122 -2.852 0.004 -0.588 -0.109
# FS_90          -0.076    0.051 -1.501 0.133 -0.176  0.023
# LocationID Var  0.339    0.182
# =========================================================
#
# Adj R-sq:  0.3887238592973421
# AIC:       1611.7305785919916
# BIC:       1665.3429633052438
# {'CamdenTown': LocationID    1.013947
# dtype: float64, 'EustonTap': LocationID    1.025579
# dtype: float64, 'MarchmontGarden': LocationID   -0.270698
# dtype: float64, 'MonumentoGaribaldi': LocationID   -0.505558
# dtype: float64, 'PancrasLock': LocationID   -0.320702
# dtype: float64, 'RegentsParkFields': LocationID   -0.079257
# dtype: float64, 'RegentsParkJapan': LocationID   -0.337626
# dtype: float64, 'RussellSq': LocationID    0.276217
# dtype: float64, 'SanMarco': LocationID   -0.960948
# dtype: float64, 'StPaulsCross': LocationID   -0.176119
# dtype: float64, 'StPaulsRow': LocationID   -0.289412
# dtype: float64, 'TateModern': LocationID   -0.051757
# dtype: float64, 'TorringtonSq': LocationID    0.676332
# dtype: float64}
#
# ##################################################
#
# WARNING: VIF of some features exceeds stated max VIF (10).
# const          1.797276
# THD_50         1.363943
# sq_S_Min       2.835417
# log_SIL_90     2.725629
# log_I_Min      1.087647
# sq_T_95        1.286526
# log_T_95       2.892623
# log_FS_90     14.826656
# log_FS_Min    13.795479
# FS_90          3.485219
# dtype: float64
#
# Removing log_FS_90: 14.826656413109061
# Traffic ~ THD_50 + sq_S_Min + log_SIL_90 + log_I_Min + sq_T_95 + log_T_95 + log_FS_Min + FS_90
# Traffic ~ THD_50 + sq_S_Min + log_SIL_90 + log_I_Min + sq_T_95 + log_T_95 + log_FS_Min + FS_90
#           Mixed Linear Model Regression Results
# =========================================================
# Model:              MixedLM Dependent Variable: Traffic
# No. Observations:   644     Method:             ML
# No. Groups:         13      Scale:              0.6624
# Min. group size:    11      Log-Likelihood:     -801.7079
# Max. group size:    81      Converged:          Yes
# Mean group size:    49.5
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       2.598    0.168 15.437 0.000  2.268  2.928
# THD_50         -0.145    0.050 -2.867 0.004 -0.243 -0.046
# sq_S_Min       -0.268    0.083 -3.239 0.001 -0.431 -0.106
# log_SIL_90      0.270    0.122  2.210 0.027  0.031  0.509
# log_I_Min       0.044    0.039  1.149 0.251 -0.031  0.120
# sq_T_95         0.060    0.027  2.191 0.028  0.006  0.113
# log_T_95       -0.112    0.059 -1.899 0.058 -0.227  0.004
# log_FS_Min      0.043    0.073  0.592 0.554 -0.100  0.187
# FS_90          -0.011    0.049 -0.235 0.814 -0.107  0.084
# LocationID Var  0.332    0.177
# =========================================================
#
# Adj R-sq:  0.37403021000912917
# AIC:       1625.415852813334
# BIC:       1674.5605388004817
# {'CamdenTown': LocationID    1.002185
# dtype: float64, 'EustonTap': LocationID    0.994566
# dtype: float64, 'MarchmontGarden': LocationID   -0.230538
# dtype: float64, 'MonumentoGaribaldi': LocationID   -0.519404
# dtype: float64, 'PancrasLock': LocationID   -0.333187
# dtype: float64, 'RegentsParkFields': LocationID   -0.078329
# dtype: float64, 'RegentsParkJapan': LocationID   -0.368767
# dtype: float64, 'RussellSq': LocationID    0.251414
# dtype: float64, 'SanMarco': LocationID   -0.940528
# dtype: float64, 'StPaulsCross': LocationID   -0.155786
# dtype: float64, 'StPaulsRow': LocationID   -0.258664
# dtype: float64, 'TateModern': LocationID   -0.061868
# dtype: float64, 'TorringtonSq': LocationID    0.698903
# dtype: float64}

# %%
plt.scatter(Traffic_model.fittedvalues - Traffic_model.resid, Traffic_model.resid, alpha=0.5)
plt.title("Residual vs. Fitted for Traffic model")
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.show()

# %%
plt.scatter(Traffic_model.fittedvalues, prelockdownData["Traffic"], alpha=0.5)
plt.title("Actual vs. Fitted for Traffic model")
plt.xlabel("Fitted values")
plt.ylabel("Actual values")
plt.show()

# %% [markdown]
# ## `Human` Model

# %%
Human_model, Human_back, Human_foward, Human_vif = mlm_model_building(prelockdownData, "Human", acoustic_vars, "LocationID", criterion="aic", check_vif = True, max_vif = 10, verbose=False)
# Out:
# Running Backward step feature selection.
# Selected features:  ['sq_FS', 'sq_FS_5', 'FS_95', 'log_FS_95', 'sq_FS_95', 'FS_Min', 'sq_FS_Min', 'LAeq', 'log_LAeq', 'sq_LAeq', 'LAeq_10', 'log_LAeq_10', 'sq_LAeq_10', 'LAeq_90', 'log_LAeq_90', 'sq_LAeq_90', 'LAeq_Max', 'log_LAeq_Min', 'sq_LAeq_Min', 'LAeq_Max_LAeq_Min', 'N_5', 'sq_N_5', 'N_10', 'N_50', 'log_N_50', 'sq_N_50', 'log_N_90', 'sq_N_90', 'sq_N_95', 'sq_N_Max', 'N_10_N_90', 'N_Max_N_Min', 'sq_R', 'R_5', 'sq_R_5', 'R_10', 'sq_R_10', 'log_R_95', 'S_Max', 'log_S_Max', 'sq_S_Max', 'SIL_5', 'log_SIL_5', 'sq_SIL_5', 'log_SIL_10', 'sq_SIL_10', 'SIL_50', 'log_SIL_50', 'sq_SIL_50', 'log_SIL_90', 'sq_SIL_90', 'SIL_95', 'log_SIL_95', 'sq_SIL_95', 'SIL_10_SIL_90', 'sq_T_5', 'sq_T_95', 'sq_T_Max', 'sq_I_5', 'sq_I_10', 'I_90', 'I_95', 'log_I_95', 'sq_I_95', 'I_Max', 'sq_I_5_I_95', 'I_10_I_90', 'sq_I_10_I_90', 'log_LCeq_5', 'log_LCeq_10', 'log_LCeq_90', 'log_LCeq_95', 'LCeq_5_LCeq_95', 'LCeq_10_LCeq_90', 'LZeq', 'log_LZeq', 'sq_LZeq', 'LZeq_5', 'log_LZeq_5', 'sq_LZeq_5', 'log_LZeq_10', 'LZeq_50', 'log_LZeq_50', 'LZeq_90', 'log_LZeq_Min', 'LZeq_Max', 'LZeq_10_LZeq_90', 'LZeq_Max_LZeq_Min', 'THD_5_THD_95', 'THD_10_THD_90']
#               Mixed Linear Model Regression Results
# ==================================================================
# Model:                 MixedLM    Dependent Variable:    Human
# No. Observations:      644        Method:                ML
# No. Groups:            13         Scale:                 0.3990
# Min. group size:       11         Log-Likelihood:        -633.6896
# Max. group size:       81         Converged:             Yes
# Mean group size:       49.5
# ------------------------------------------------------------------
#                    Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# ------------------------------------------------------------------
# Intercept            3.040    0.124 24.560 0.000    2.798    3.283
# sq_FS               -0.407    0.166 -2.448 0.014   -0.733   -0.081
# sq_FS_5              0.284    0.088  3.241 0.001    0.112    0.456
# FS_95               -1.294    0.381 -3.400 0.001   -2.040   -0.548
# log_FS_95            0.335    0.137  2.442 0.015    0.066    0.603
# sq_FS_95             1.509    0.554  2.725 0.006    0.424    2.595
# FS_Min               0.999    0.282  3.539 0.000    0.446    1.552
# sq_FS_Min           -1.295    0.497 -2.603 0.009   -2.270   -0.320
# LAeq              -166.083   79.150 -2.098 0.036 -321.214  -10.953
# log_LAeq            81.127   39.195  2.070 0.038    4.306  157.947
# sq_LAeq             86.101   40.245  2.139 0.032    7.221  164.980
# LAeq_10            167.857   64.006  2.623 0.009   42.408  293.306
# log_LAeq_10        -81.223   32.137 -2.527 0.011 -144.210  -18.236
# sq_LAeq_10         -88.285   32.179 -2.744 0.006 -151.355  -25.215
# LAeq_90           -267.854   78.103 -3.430 0.001 -420.932 -114.775
# log_LAeq_90        138.669   40.289  3.442 0.001   59.704  217.635
# sq_LAeq_90         130.728   38.440  3.401 0.001   55.386  206.070
# LAeq_Max           253.817   74.136  3.424 0.001  108.512  399.121
# log_LAeq_Min      -113.568   34.589 -3.283 0.001 -181.361  -45.775
# sq_LAeq_Min       -113.523   32.056 -3.541 0.000 -176.351  -50.695
# LAeq_Max_LAeq_Min -172.619   50.376 -3.427 0.001 -271.353  -73.884
# N_5                  3.536    1.084  3.262 0.001    1.411    5.661
# sq_N_5              -2.596    0.647 -4.014 0.000   -3.864   -1.328
# N_10                23.781    9.659  2.462 0.014    4.849   42.713
# N_50               -17.381    5.914 -2.939 0.003  -28.973   -5.789
# log_N_50            10.123    4.046  2.502 0.012    2.192   18.054
# sq_N_50              9.543    3.158  3.022 0.003    3.354   15.733
# log_N_90           -15.378    4.874 -3.155 0.002  -24.930   -5.826
# sq_N_90            -10.570    3.620 -2.920 0.003  -17.664   -3.476
# sq_N_95              3.288    1.322  2.487 0.013    0.697    5.878
# sq_N_Max            -0.606    0.279 -2.174 0.030   -1.152   -0.060
# N_10_N_90          -13.006    4.939 -2.633 0.008  -22.685   -3.326
# N_Max_N_Min          0.603    0.276  2.187 0.029    0.063    1.143
# sq_R                 1.256    0.346  3.633 0.000    0.578    1.933
# R_5                 -1.645    0.460 -3.573 0.000   -2.547   -0.743
# sq_R_5               1.932    0.549  3.519 0.000    0.856    3.008
# R_10                 1.494    0.558  2.678 0.007    0.401    2.588
# sq_R_10             -2.166    0.555 -3.902 0.000   -3.253   -1.078
# log_R_95            -0.693    0.188 -3.684 0.000   -1.062   -0.324
# S_Max               -5.124    1.649 -3.107 0.002   -8.356   -1.891
# log_S_Max            2.749    0.992  2.771 0.006    0.804    4.693
# sq_S_Max             2.692    0.796  3.381 0.001    1.131    4.253
# SIL_5              154.043   47.087  3.271 0.001   61.754  246.332
# log_SIL_5          -84.025   24.841 -3.383 0.001 -132.713  -35.338
# sq_SIL_5           -72.999   22.776 -3.205 0.001 -117.639  -28.358
# log_SIL_10         155.441   34.753  4.473 0.000   87.326  223.556
# sq_SIL_10          145.077   31.703  4.576 0.000   82.940  207.214
# SIL_50             163.935   63.322  2.589 0.010   39.826  288.044
# log_SIL_50         -91.897   33.573 -2.737 0.006 -157.699  -26.094
# sq_SIL_50          -74.120   30.671 -2.417 0.016 -134.233  -14.006
# log_SIL_90        -143.350   33.590 -4.268 0.000 -209.185  -77.516
# sq_SIL_90         -140.338   31.013 -4.525 0.000 -201.122  -79.554
# SIL_95            -260.449   84.149 -3.095 0.002 -425.377  -95.520
# log_SIL_95         139.302   45.033  3.093 0.002   51.038  227.565
# sq_SIL_95          123.270   40.443  3.048 0.002   44.003  202.536
# SIL_10_SIL_90     -128.087   28.364 -4.516 0.000 -183.679  -72.495
# sq_T_5               0.326    0.065  4.988 0.000    0.198    0.453
# sq_T_95              0.046    0.020  2.339 0.019    0.007    0.084
# sq_T_Max            -0.137    0.052 -2.627 0.009   -0.240   -0.035
# sq_I_5               4.160    1.420  2.929 0.003    1.376    6.943
# sq_I_10             -6.482    1.747 -3.710 0.000   -9.907   -3.057
# I_90                 1.218    0.461  2.643 0.008    0.315    2.121
# I_95                -8.018    3.221 -2.489 0.013  -14.331   -1.705
# log_I_95             4.088    1.855  2.204 0.028    0.452    7.725
# sq_I_95              4.184    1.672  2.502 0.012    0.907    7.462
# I_Max               -0.124    0.050 -2.495 0.013   -0.222   -0.027
# sq_I_5_I_95         -3.633    1.314 -2.764 0.006   -6.208   -1.057
# I_10_I_90            1.045    0.382  2.737 0.006    0.297    1.793
# sq_I_10_I_90         4.343    1.305  3.327 0.001    1.785    6.902
# log_LCeq_5          20.269    5.648  3.588 0.000    9.198   31.339
# log_LCeq_10        -33.591    6.851 -4.903 0.000  -47.018  -20.163
# log_LCeq_90         35.586    6.866  5.183 0.000   22.130   49.043
# log_LCeq_95        -20.671    5.685 -3.636 0.000  -31.813   -9.529
# LCeq_5_LCeq_95     -11.875    3.324 -3.572 0.000  -18.391   -5.360
# LCeq_10_LCeq_90     16.866    3.441  4.901 0.000   10.121   23.611
# LZeq               161.808   65.311  2.478 0.013   33.801  289.816
# log_LZeq           -76.375   32.323 -2.363 0.018 -139.728  -13.023
# sq_LZeq            -86.717   33.837 -2.563 0.010 -153.037  -20.397
# LZeq_5            -156.729   59.549 -2.632 0.008 -273.444  -40.015
# log_LZeq_5          63.338   29.490  2.148 0.032    5.539  121.137
# sq_LZeq_5           93.285   30.586  3.050 0.002   33.339  153.232
# log_LZeq_10         34.936    7.164  4.876 0.000   20.894   48.977
# LZeq_50             10.159    4.169  2.437 0.015    1.989   18.330
# log_LZeq_50        -10.216    4.191 -2.438 0.015  -18.430   -2.003
# LZeq_90            -30.687    6.249 -4.911 0.000  -42.934  -18.439
# log_LZeq_Min        -6.534    2.569 -2.544 0.011  -11.569   -1.499
# LZeq_Max             7.806    3.055  2.555 0.011    1.818   13.794
# LZeq_10_LZeq_90    -19.657    4.070 -4.830 0.000  -27.634  -11.681
# LZeq_Max_LZeq_Min   -6.674    2.631 -2.536 0.011  -11.831   -1.516
# THD_5_THD_95         0.478    0.136  3.500 0.000    0.210    0.745
# THD_10_THD_90       -0.530    0.137 -3.870 0.000   -0.799   -0.262
# LocationID Var       0.090    0.084
# ==================================================================
#
# Adj R-sq: 0.38734230268835557
# AIC:       1453.379105375503
# BIC:       1868.8750869032078
#
# ##################################################
# Running Forward step feature selection.
# Human ~ log_FS_95 + sq_N_5 + sq_T_5 + SIL_95 + sq_R_5 + log_N_90 + log_LCeq_90
#           Mixed Linear Model Regression Results
# =========================================================
# Model:              MixedLM Dependent Variable: Human
# No. Observations:   644     Method:             ML
# No. Groups:         13      Scale:              0.5190
# Min. group size:    11      Log-Likelihood:     -720.1860
# Max. group size:    81      Converged:          Yes
# Mean group size:    49.5
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       3.017    0.119 25.330 0.000  2.783  3.250
# log_FS_95       0.113    0.040  2.843 0.004  0.035  0.192
# sq_N_5         -0.229    0.051 -4.510 0.000 -0.328 -0.129
# sq_T_5          0.108    0.034  3.197 0.001  0.042  0.174
# SIL_95          1.350    0.484  2.787 0.005  0.401  2.299
# sq_R_5          0.054    0.031  1.724 0.085 -0.007  0.116
# log_N_90       -1.547    0.592 -2.612 0.009 -2.708 -0.386
# log_LCeq_90     0.346    0.165  2.093 0.036  0.022  0.669
# LocationID Var  0.161    0.099
# =========================================================
#
# Adj R-sq:  0.3076576431797694
# AIC:       1460.3720794571082
# BIC:       1505.0490667181516
# {'CamdenTown': LocationID    0.235238
# dtype: float64, 'EustonTap': LocationID   -0.448243
# dtype: float64, 'MarchmontGarden': LocationID   -0.448108
# dtype: float64, 'MonumentoGaribaldi': LocationID    0.198073
# dtype: float64, 'PancrasLock': LocationID   -0.645536
# dtype: float64, 'RegentsParkFields': LocationID   -0.095397
# dtype: float64, 'RegentsParkJapan': LocationID   -0.45347
# dtype: float64, 'RussellSq': LocationID   -0.052876
# dtype: float64, 'SanMarco': LocationID    0.700685
# dtype: float64, 'StPaulsCross': LocationID    0.195858
# dtype: float64, 'StPaulsRow': LocationID    0.135308
# dtype: float64, 'TateModern': LocationID    0.440726
# dtype: float64, 'TorringtonSq': LocationID    0.237742
# dtype: float64}
#
# ##################################################
#
# WARNING: VIF of some features exceeds stated max VIF (10).
# const            1.461943
# log_FS_95        1.249064
# sq_N_5           3.251353
# sq_T_5           1.960008
# SIL_95         166.058267
# sq_R_5           1.141262
# log_N_90       224.940925
# log_LCeq_90     12.882788
# dtype: float64
#
# Removing log_N_90: 224.94092458841496
# Human ~ log_FS_95 + sq_N_5 + sq_T_5 + SIL_95 + sq_R_5 + log_LCeq_90
# Human ~ log_FS_95 + sq_N_5 + sq_T_5 + SIL_95 + sq_R_5 + log_LCeq_90
#           Mixed Linear Model Regression Results
# =========================================================
# Model:              MixedLM Dependent Variable: Human
# No. Observations:   644     Method:             ML
# No. Groups:         13      Scale:              0.5256
# Min. group size:    11      Log-Likelihood:     -723.5814
# Max. group size:    81      Converged:          Yes
# Mean group size:    49.5
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       2.999    0.114 26.303 0.000  2.775  3.222
# log_FS_95       0.142    0.039  3.695 0.000  0.067  0.218
# sq_N_5         -0.221    0.051 -4.347 0.000 -0.321 -0.121
# sq_T_5          0.104    0.034  3.071 0.002  0.038  0.171
# SIL_95          0.115    0.106  1.082 0.279 -0.093  0.323
# sq_R_5          0.047    0.032  1.482 0.138 -0.015  0.109
# log_LCeq_90     0.024    0.110  0.219 0.827 -0.192  0.240
# LocationID Var  0.146    0.089
# =========================================================
#
# Adj R-sq:  0.2998694508634271
# AIC:       1465.1627725618382
# BIC:       1505.3720610967773
# {'CamdenTown': LocationID    0.260359
# dtype: float64, 'EustonTap': LocationID   -0.431394
# dtype: float64, 'MarchmontGarden': LocationID   -0.357409
# dtype: float64, 'MonumentoGaribaldi': LocationID    0.119619
# dtype: float64, 'PancrasLock': LocationID   -0.601652
# dtype: float64, 'RegentsParkFields': LocationID   -0.052099
# dtype: float64, 'RegentsParkJapan': LocationID   -0.459249
# dtype: float64, 'RussellSq': LocationID   -0.089642
# dtype: float64, 'SanMarco': LocationID    0.708425
# dtype: float64, 'StPaulsCross': LocationID    0.1853
# dtype: float64, 'StPaulsRow': LocationID    0.16244
# dtype: float64, 'TateModern': LocationID    0.415088
# dtype: float64, 'TorringtonSq': LocationID    0.140214
# dtype: float64}

# %%
plt.scatter(Human_model.fittedvalues - Human_model.resid, Human_model.resid, alpha=0.5)
plt.title("Residual vs. Fitted for Human model")
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.show()

# %%
plt.scatter(Human_model.fittedvalues, prelockdownData["Human"], alpha=0.5)
plt.title("Actual vs. Fitted for Human model")
plt.xlabel("Fitted values")
plt.ylabel("Actual values")
plt.show()

# %% [markdown]
# ## `Other` model

# %%
Other_model, Other_back, Other_foward, Other_vif = mlm_model_building(prelockdownData, "Other", acoustic_vars, "LocationID", criterion="aic", check_vif = True, max_vif = 10, verbose=False)
# Out:
# Running Backward step feature selection.
# Selected features:  ['sq_LAeq', 'N_5', 'sq_N_10', 'N_50', 'log_N_50', 'N_90', 'log_N_90', 'sq_N_90', 'log_N_95', 'sq_N_95', 'N_Min', 'sq_N_Min', 'N_Max', 'log_N_Max', 'sq_N_Max', 'N_5_N_95', 'N_10_N_90', 'S', 'log_S', 'sq_S', 'S_50', 'log_S_50', 'sq_S_50', 'sq_SIL_10', 'SIL_50', 'log_SIL_50', 'log_SIL_90', 'SIL_10_SIL_90', 'PeakSpectralCentroid', 'log_PeakSpectralCentroid', 'sq_PeakSpectralCentroid', 'log_PeakMaxFreq', 'I_10', 'log_I_90', 'sq_I_90', 'I_95', 'log_I_95', 'sq_I_95', 'I_10_I_90', 'LCeq', 'sq_LCeq', 'LCeq_5', 'LCeq_50', 'log_LCeq_50', 'sq_LCeq_50', 'log_LCeq_95', 'sq_LCeq_95', 'LCeq_5_LCeq_95', 'sq_LZeq', 'log_LZeq_10', 'sq_LZeq_10', 'LZeq_90', 'LZeq_95', 'log_LZeq_95', 'sq_LZeq_95', 'sq_LZeq_Min', 'LZeq_Max', 'LZeq_10_LZeq_90', 'LZeq_Max_LZeq_Min']
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                  MixedLM       Dependent Variable:       Other
# No. Observations:       644           Method:                   ML
# No. Groups:             13            Scale:                    0.6994
# Min. group size:        11            Log-Likelihood:           -812.4629
# Max. group size:        81            Converged:                Yes
# Mean group size:        49.5
# -------------------------------------------------------------------------
#                           Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# -------------------------------------------------------------------------
# Intercept                   2.414    0.208 11.625 0.000    2.007    2.821
# sq_LAeq                    -1.279    0.502 -2.547 0.011   -2.264   -0.295
# N_5                        68.640   20.967  3.274 0.001   27.545  109.736
# sq_N_10                    -3.140    0.685 -4.582 0.000   -4.483   -1.797
# N_50                        5.903    1.987  2.972 0.003    2.010    9.797
# log_N_50                   -9.815    2.671 -3.675 0.000  -15.049   -4.581
# N_90                      -47.823   12.667 -3.775 0.000  -72.650  -22.996
# log_N_90                   39.949   10.023  3.986 0.000   20.304   59.594
# sq_N_90                    22.985    5.666  4.056 0.000   11.879   34.091
# log_N_95                  -34.457    9.152 -3.765 0.000  -52.394  -16.520
# sq_N_95                   -18.836    5.848 -3.221 0.001  -30.297   -7.375
# N_Min                       4.716    1.549  3.044 0.002    1.679    7.752
# sq_N_Min                   -3.654    1.141 -3.203 0.001   -5.890   -1.418
# N_Max                      -2.338    0.842 -2.778 0.005   -3.988   -0.688
# log_N_Max                   1.434    0.559  2.565 0.010    0.338    2.529
# sq_N_Max                    1.236    0.428  2.886 0.004    0.396    2.075
# N_5_N_95                  -41.207   12.382 -3.328 0.001  -65.475  -16.939
# N_10_N_90                   2.134    0.547  3.904 0.000    1.063    3.206
# S                         -90.322   34.878 -2.590 0.010 -158.681  -21.963
# log_S                      50.190   18.473  2.717 0.007   13.984   86.395
# sq_S                       44.900   18.106  2.480 0.013    9.412   80.387
# S_50                       86.157   34.672  2.485 0.013   18.201  154.113
# log_S_50                  -48.453   18.377 -2.637 0.008  -84.471  -12.435
# sq_S_50                   -42.558   18.014 -2.362 0.018  -77.864   -7.251
# sq_SIL_10                  11.474    2.949  3.891 0.000    5.694   17.254
# SIL_50                    -19.548    6.363 -3.072 0.002  -32.019   -7.078
# log_SIL_50                 22.777    6.833  3.333 0.001    9.384   36.170
# log_SIL_90                -11.442    3.365 -3.400 0.001  -18.037   -4.847
# SIL_10_SIL_90              -4.960    1.302 -3.809 0.000   -7.513   -2.408
# PeakSpectralCentroid       53.768   22.858  2.352 0.019    8.968   98.568
# log_PeakSpectralCentroid  -30.989   12.883 -2.405 0.016  -56.240   -5.739
# sq_PeakSpectralCentroid   -23.994   10.382 -2.311 0.021  -44.343   -3.645
# log_PeakMaxFreq             0.179    0.051  3.506 0.000    0.079    0.279
# I_10                      218.184   65.896  3.311 0.001   89.030  347.337
# log_I_90                  -29.963    9.233 -3.245 0.001  -48.059  -11.867
# sq_I_90                   -28.176    8.378 -3.363 0.001  -44.595  -11.756
# I_95                      -52.188   16.764 -3.113 0.002  -85.045  -19.332
# log_I_95                   31.491   10.114  3.114 0.002   11.669   51.313
# sq_I_95                    25.396    8.216  3.091 0.002    9.292   41.499
# I_10_I_90                -184.651   55.784 -3.310 0.001 -293.986  -75.316
# LCeq                      -12.379    5.128 -2.414 0.016  -22.430   -2.327
# sq_LCeq                    14.223    5.042  2.821 0.005    4.341   24.106
# LCeq_5                   -425.479  150.838 -2.821 0.005 -721.116 -129.842
# LCeq_50                   296.863   97.786  3.036 0.002  105.205  488.520
# log_LCeq_50              -150.499   51.132 -2.943 0.003 -250.715  -50.282
# sq_LCeq_50               -147.894   47.365 -3.122 0.002 -240.728  -55.060
# log_LCeq_95               209.682   73.077  2.869 0.004   66.455  352.909
# sq_LCeq_95                189.287   68.728  2.754 0.006   54.582  323.992
# LCeq_5_LCeq_95            255.128   90.699  2.813 0.005   77.361  432.895
# sq_LZeq                    -1.688    0.765 -2.207 0.027   -3.186   -0.189
# log_LZeq_10                68.799   18.794  3.661 0.000   31.963  105.635
# sq_LZeq_10                 61.095   18.541  3.295 0.001   24.755   97.434
# LZeq_90                  -117.029   33.193 -3.526 0.000 -182.086  -51.972
# LZeq_95                   254.689  106.342  2.395 0.017   46.261  463.116
# log_LZeq_95              -124.183   53.393 -2.326 0.020 -228.832  -19.534
# sq_LZeq_95               -128.507   53.562 -2.399 0.016 -233.487  -23.527
# sq_LZeq_Min                17.273    5.517  3.131 0.002    6.460   28.086
# LZeq_Max                  -22.242    7.023 -3.167 0.002  -36.007   -8.477
# LZeq_10_LZeq_90           -75.333   21.794 -3.457 0.001 -118.049  -32.617
# LZeq_Max_LZeq_Min          19.532    6.060  3.223 0.001    7.655   31.410
# LocationID Var              0.112    0.071
# =========================================================================
#
# Adj R-sq:  0.2679065877982708
# AIC:       1748.925888229658
# BIC:       2025.923209248128
#
# ##################################################
# Running Forward step feature selection.
# Other ~ log_PeakSpectralCentroid + log_PeakMaxFreq + S_50 + log_I_90 + LZeq_Max + LCeq_5_LCeq_95 + N_Min + S
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                MixedLM     Dependent Variable:     Other
# No. Observations:     644         Method:                 ML
# No. Groups:           13          Scale:                  0.8229
# Min. group size:      11          Log-Likelihood:         -866.8704
# Max. group size:      81          Converged:              Yes
# Mean group size:      49.5
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 2.383    0.135 17.711 0.000  2.120  2.647
# log_PeakSpectralCentroid -0.168    0.087 -1.937 0.053 -0.338  0.002
# log_PeakMaxFreq           0.114    0.043  2.671 0.008  0.030  0.197
# S_50                     -0.599    0.403 -1.488 0.137 -1.389  0.190
# log_I_90                 -0.109    0.052 -2.103 0.035 -0.211 -0.007
# LZeq_Max                  0.266    0.079  3.378 0.001  0.112  0.421
# LCeq_5_LCeq_95           -0.236    0.077 -3.068 0.002 -0.387 -0.085
# N_Min                    -0.228    0.111 -2.061 0.039 -0.445 -0.011
# S                         0.576    0.402  1.432 0.152 -0.212  1.364
# LocationID Var            0.190    0.097
# ===================================================================
#
# Adj R-sq:  0.20855925525036134
# AIC:       1755.7407123254907
# BIC:       1804.8853983126385
# {'CamdenTown': LocationID    0.473661
# dtype: float64, 'EustonTap': LocationID    0.650193
# dtype: float64, 'MarchmontGarden': LocationID   -0.063595
# dtype: float64, 'MonumentoGaribaldi': LocationID   -0.21481
# dtype: float64, 'PancrasLock': LocationID    0.594934
# dtype: float64, 'RegentsParkFields': LocationID   -0.446741
# dtype: float64, 'RegentsParkJapan': LocationID   -0.625659
# dtype: float64, 'RussellSq': LocationID   -0.158741
# dtype: float64, 'SanMarco': LocationID   -0.285413
# dtype: float64, 'StPaulsCross': LocationID   -0.20575
# dtype: float64, 'StPaulsRow': LocationID   -0.09079
# dtype: float64, 'TateModern': LocationID   -0.235618
# dtype: float64, 'TorringtonSq': LocationID    0.608328
# dtype: float64}
#
# ##################################################
#
# WARNING: VIF of some features exceeds stated max VIF (10).
# const                        1.984762
# log_PeakSpectralCentroid     1.557288
# log_PeakMaxFreq              1.431256
# S_50                        98.180072
# log_I_90                     1.288663
# LZeq_Max                     3.525364
# LCeq_5_LCeq_95               2.105250
# N_Min                        4.517227
# S                           99.887613
# dtype: float64
#
# Removing S: 99.8876126919988
# Other ~ log_PeakSpectralCentroid + log_PeakMaxFreq + S_50 + log_I_90 + LZeq_Max + LCeq_5_LCeq_95 + N_Min
# Other ~ log_PeakSpectralCentroid + log_PeakMaxFreq + S_50 + log_I_90 + LZeq_Max + LCeq_5_LCeq_95 + N_Min
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                MixedLM     Dependent Variable:     Other
# No. Observations:     644         Method:                 ML
# No. Groups:           13          Scale:                  0.8254
# Min. group size:      11          Log-Likelihood:         -867.8945
# Max. group size:      81          Converged:              Yes
# Mean group size:      49.5
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 2.374    0.135 17.577 0.000  2.109  2.639
# log_PeakSpectralCentroid -0.132    0.083 -1.585 0.113 -0.295  0.031
# log_PeakMaxFreq           0.125    0.042  2.985 0.003  0.043  0.207
# S_50                     -0.041    0.102 -0.405 0.686 -0.242  0.159
# log_I_90                 -0.109    0.052 -2.106 0.035 -0.211 -0.008
# LZeq_Max                  0.276    0.079  3.503 0.000  0.121  0.430
# LCeq_5_LCeq_95           -0.213    0.075 -2.829 0.005 -0.361 -0.066
# N_Min                    -0.227    0.111 -2.045 0.041 -0.444 -0.009
# LocationID Var            0.192    0.097
# ===================================================================
#
# Adj R-sq:  0.20741996253462547
# AIC:       1755.7889398930683
# BIC:       1800.4659271541118
# {'CamdenTown': LocationID    0.500345
# dtype: float64, 'EustonTap': LocationID    0.670296
# dtype: float64, 'MarchmontGarden': LocationID   -0.047829
# dtype: float64, 'MonumentoGaribaldi': LocationID   -0.243071
# dtype: float64, 'PancrasLock': LocationID    0.598599
# dtype: float64, 'RegentsParkFields': LocationID   -0.451036
# dtype: float64, 'RegentsParkJapan': LocationID   -0.596922
# dtype: float64, 'RussellSq': LocationID   -0.153172
# dtype: float64, 'SanMarco': LocationID   -0.300746
# dtype: float64, 'StPaulsCross': LocationID   -0.217667
# dtype: float64, 'StPaulsRow': LocationID   -0.101111
# dtype: float64, 'TateModern': LocationID   -0.242994
# dtype: float64, 'TorringtonSq': LocationID    0.585308
# dtype: float64}

# %%
plt.scatter(Other_model.fittedvalues - Other_model.resid, Other_model.resid, alpha=0.5)
plt.title("Residual vs. Fitted for Other model")
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.show()

# %%
plt.scatter(Other_model.fittedvalues, prelockdownData["Other"], alpha=0.5)
plt.title("Actual vs. Fitted for Other model")
plt.xlabel("Fitted values")
plt.ylabel("Actual values")
plt.show()

# %% [markdown]
# ## `Pleasant` model

# %%
Pleasant_model, Pleasant_back, Pleasant_forward, Pleasant_vif = mlm_model_building(prelockdownData, "Pleasant", acoustic_vars, "LocationID", criterion="aic", verbose=False)
# Out:
# Running Backward step feature selection.
# Selected features:  ['FS_10_FS_90', 'LAeq_50', 'log_LAeq_50', 'R_90', 'sq_SIL_50', 'I', 'log_I', 'log_LCeq_95', 'log_LCeq_Min', 'LCeq_Max', 'LCeq_Max_LCeq_Min']
#            Mixed Linear Model Regression Results
# ============================================================
# Model:               MixedLM  Dependent Variable:  Pleasant
# No. Observations:    644      Method:              ML
# No. Groups:          13       Scale:               0.0839
# Min. group size:     11       Log-Likelihood:      -129.6328
# Max. group size:     81       Converged:           Yes
# Mean group size:     49.5
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          0.295    0.038  7.820 0.000  0.221  0.369
# FS_10_FS_90        0.023    0.011  2.050 0.040  0.001  0.046
# LAeq_50            2.747    0.637  4.314 0.000  1.499  3.995
# log_LAeq_50       -1.923    0.502 -3.830 0.000 -2.907 -0.939
# R_90              -0.243    0.067 -3.609 0.000 -0.375 -0.111
# sq_SIL_50         -0.843    0.185 -4.551 0.000 -1.206 -0.480
# I                  0.254    0.079  3.203 0.001  0.099  0.410
# log_I             -0.259    0.082 -3.141 0.002 -0.420 -0.097
# log_LCeq_95       -0.417    0.135 -3.096 0.002 -0.682 -0.153
# log_LCeq_Min       1.913    0.554  3.454 0.001  0.828  2.999
# LCeq_Max          -1.610    0.560 -2.872 0.004 -2.708 -0.511
# LCeq_Max_LCeq_Min  1.248    0.444  2.812 0.005  0.378  2.118
# LocationID Var     0.014    0.023
# ============================================================
#
# Adj R-sq:  0.40898048809371945
# AIC:       287.2656133511473
# BIC:       349.81339551660824
#
# ##################################################
# Running Forward step feature selection.
# Pleasant ~ sq_SIL_50 + LCeq_Max + FS_10_FS_90 + LAeq_50 + R_90 + log_LAeq_50
#           Mixed Linear Model Regression Results
# =========================================================
# Model:              MixedLM Dependent Variable: Pleasant
# No. Observations:   644     Method:             ML
# No. Groups:         13      Scale:              0.0862
# Min. group size:    11      Log-Likelihood:     -140.7280
# Max. group size:    81      Converged:          Yes
# Mean group size:    49.5
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       0.293    0.044  6.740 0.000  0.208  0.379
# sq_SIL_50      -0.622    0.178 -3.494 0.000 -0.970 -0.273
# LCeq_Max       -0.051    0.021 -2.456 0.014 -0.092 -0.010
# FS_10_FS_90     0.022    0.011  2.015 0.044  0.001  0.043
# LAeq_50         1.507    0.538  2.799 0.005  0.451  2.562
# R_90           -0.188    0.061 -3.062 0.002 -0.309 -0.068
# log_LAeq_50    -0.869    0.386 -2.254 0.024 -1.625 -0.113
# LocationID Var  0.020    0.032
# =========================================================
#
# Adj R-sq:  0.3975268622856818
# AIC:       299.45592057876183
# BIC:       339.665209113701
# {'CamdenTown': LocationID   -0.149547
# dtype: float64, 'EustonTap': LocationID   -0.277495
# dtype: float64, 'MarchmontGarden': LocationID   -0.080284
# dtype: float64, 'MonumentoGaribaldi': LocationID   -0.038185
# dtype: float64, 'PancrasLock': LocationID   -0.005001
# dtype: float64, 'RegentsParkFields': LocationID    0.068778
# dtype: float64, 'RegentsParkJapan': LocationID    0.197642
# dtype: float64, 'RussellSq': LocationID    0.22134
# dtype: float64, 'SanMarco': LocationID    0.045301
# dtype: float64, 'StPaulsCross': LocationID    0.108046
# dtype: float64, 'StPaulsRow': LocationID   -0.033752
# dtype: float64, 'TateModern': LocationID    0.081624
# dtype: float64, 'TorringtonSq': LocationID   -0.138466
# dtype: float64}
#
# ##################################################
#
# WARNING: VIF of some features exceeds stated max VIF (10).
# const             1.647217
# sq_SIL_50       165.643968
# LCeq_Max          2.470751
# FS_10_FS_90       1.114846
# LAeq_50        1355.943898
# R_90              7.997811
# log_LAeq_50     588.701029
# dtype: float64
#
# Removing LAeq_50: 1355.9438981081319
# Pleasant ~ sq_SIL_50 + LCeq_Max + FS_10_FS_90 + R_90 + log_LAeq_50
#
# Removing log_LAeq_50: 35.98061136798732
# Pleasant ~ sq_SIL_50 + LCeq_Max + FS_10_FS_90 + R_90
# Pleasant ~ sq_SIL_50 + LCeq_Max + FS_10_FS_90 + R_90
#           Mixed Linear Model Regression Results
# =========================================================
# Model:              MixedLM Dependent Variable: Pleasant
# No. Observations:   644     Method:             ML
# No. Groups:         13      Scale:              0.0874
# Min. group size:    11      Log-Likelihood:     -145.9593
# Max. group size:    81      Converged:          Yes
# Mean group size:    49.5
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       0.283    0.046  6.108 0.000  0.192  0.374
# sq_SIL_50      -0.056    0.036 -1.574 0.115 -0.126  0.014
# LCeq_Max       -0.043    0.021 -2.056 0.040 -0.084 -0.002
# FS_10_FS_90     0.023    0.011  2.191 0.028  0.002  0.044
# R_90           -0.051    0.044 -1.169 0.243 -0.137  0.035
# LocationID Var  0.025    0.037
# =========================================================
#
# Adj R-sq:  0.3917035916789936
# AIC:       305.9186277113022
# BIC:       337.19251879403265
# {'CamdenTown': LocationID   -0.16607
# dtype: float64, 'EustonTap': LocationID   -0.309691
# dtype: float64, 'MarchmontGarden': LocationID   -0.089415
# dtype: float64, 'MonumentoGaribaldi': LocationID   -0.032562
# dtype: float64, 'PancrasLock': LocationID   -0.012528
# dtype: float64, 'RegentsParkFields': LocationID    0.075575
# dtype: float64, 'RegentsParkJapan': LocationID    0.217255
# dtype: float64, 'RussellSq': LocationID    0.247494
# dtype: float64, 'SanMarco': LocationID    0.050834
# dtype: float64, 'StPaulsCross': LocationID    0.097646
# dtype: float64, 'StPaulsRow': LocationID   -0.042028
# dtype: float64, 'TateModern': LocationID    0.110895
# dtype: float64, 'TorringtonSq': LocationID   -0.147404
# dtype: float64}

# %%
plt.scatter(Pleasant_model.fittedvalues - Pleasant_model.resid, Pleasant_model.resid, alpha=0.5)
plt.title("Residual vs. Fitted for Pleasant model")
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.show()

# %%
plt.scatter(Pleasant_model.fittedvalues, prelockdownData["Pleasant"], alpha=0.5)
plt.title("Actual vs. Fitted for Pleasant model")
plt.xlabel("Fitted values")
plt.ylabel("Actual values")
plt.show()

# %% [markdown]
# ## `Eventful` model

# %%
Eventful_model, Eventful_back, Eventful_forward, Eventful_vif = mlm_model_building(prelockdownData, "Eventful", acoustic_vars, "LocationID", sig_level = 0.05, criterion="aic", verbose=False)
# Out:
# Running Backward step feature selection.
# Selected features:  ['FS', 'log_FS', 'sq_FS', 'FS_5', 'FS_50', 'sq_FS_50', 'FS_Max', 'log_FS_Max', 'sq_FS_Max', 'LAeq', 'log_LAeq', 'sq_LAeq', 'LAeq_5', 'log_LAeq_5', 'LAeq_10', 'log_LAeq_10', 'sq_LAeq_10', 'LAeq_50', 'LAeq_Max', 'log_LAeq_Min', 'sq_LAeq_Min', 'LAeq_Max_LAeq_Min', 'sq_N_5', 'N_10', 'log_N_10', 'N_50', 'log_N_50', 'sq_N_50', 'sq_N_90', 'log_N_Min', 'N_10_N_90', 'R_5', 'log_R_5', 'sq_R_5', 'log_R_10', 'sq_R_10', 'R_50', 'log_R_50', 'sq_R_50', 'sq_R_90', 'R_95', 'log_R_95', 'sq_R_95', 'log_R_Max', 'sq_R_Max', 'R_10_R_90', 'S', 'log_S', 'sq_S', 'S_5', 'log_S_5', 'sq_S_5', 'log_S_10', 'sq_S_10', 'S_50', 'log_S_50', 'sq_S_50', 'log_S_90', 'sq_S_90', 'log_S_95', 'sq_S_95', 'S_5_S_95', 'S_10_S_90', 'SIL_5', 'log_SIL_5', 'SIL_50', 'sq_SIL_50', 'SIL_Min', 'SIL_Max', 'sq_SIL_Max', 'SIL_5_SIL_95', 'sq_T_10', 'sq_PeakMaxFreq', 'I_5', 'I_50', 'log_I_50', 'sq_I_50', 'log_I_95', 'sq_I_95', 'I_Max', 'sq_I_Max', 'I_5_I_95', 'log_I_10_I_90', 'I_Max_I_Min', 'sq_I_Max_I_Min', 'log_LCeq_5', 'sq_LCeq_5', 'LCeq_10', 'log_LCeq_10', 'sq_LCeq_10', 'LCeq_50', 'sq_LCeq_50', 'LCeq_90', 'log_LCeq_90', 'sq_LCeq_90', 'log_LCeq_95', 'sq_LCeq_95', 'LCeq_5_LCeq_95', 'LZeq_5', 'log_LZeq_5', 'sq_LZeq_5', 'log_LZeq_10', 'sq_LZeq_10', 'log_LZeq_90', 'sq_LZeq_90', 'LZeq_95', 'log_LZeq_95', 'sq_LZeq_95', 'log_LZeq_Min', 'sq_LZeq_Min', 'LZeq_Max', 'LZeq_10_LZeq_90', 'LZeq_Max_LZeq_Min', 'THD_5', 'THD_95', 'THD_10_THD_90']
#               Mixed Linear Model Regression Results
# ==================================================================
# Model:                MixedLM     Dependent Variable:     Eventful
# No. Observations:     644         Method:                 ML
# No. Groups:           13          Scale:                  0.0448
# Min. group size:      11          Log-Likelihood:         74.7390
# Max. group size:      81          Converged:              Yes
# Mean group size:      49.5
# ------------------------------------------------------------------
#                    Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# ------------------------------------------------------------------
# Intercept            0.070    0.058  1.209 0.227   -0.043    0.183
# FS                  -0.940    0.185 -5.092 0.000   -1.302   -0.578
# log_FS               0.284    0.075  3.787 0.000    0.137    0.432
# sq_FS                0.839    0.158  5.300 0.000    0.529    1.150
# FS_5                 0.192    0.068  2.810 0.005    0.058    0.326
# FS_50                0.323    0.099  3.248 0.001    0.128    0.518
# sq_FS_50            -0.481    0.113 -4.272 0.000   -0.702   -0.260
# FS_Max               0.286    0.087  3.276 0.001    0.115    0.456
# log_FS_Max          -0.155    0.060 -2.581 0.010   -0.273   -0.037
# sq_FS_Max           -0.333    0.073 -4.570 0.000   -0.476   -0.190
# LAeq               -83.335   23.820 -3.498 0.000 -130.021  -36.648
# log_LAeq            38.828   11.878  3.269 0.001   15.547   62.108
# sq_LAeq             45.446   12.031  3.777 0.000   21.866   69.026
# LAeq_5              -5.009    1.814 -2.761 0.006   -8.564   -1.453
# log_LAeq_5           5.021    1.837  2.733 0.006    1.420    8.622
# LAeq_10             46.233   18.594  2.486 0.013    9.790   82.676
# log_LAeq_10        -23.577    9.609 -2.454 0.014  -42.410   -4.744
# sq_LAeq_10         -23.320    9.134 -2.553 0.011  -41.222   -5.418
# LAeq_50             -0.652    0.326 -1.999 0.046   -1.292   -0.013
# LAeq_Max            32.937   14.039  2.346 0.019    5.421   60.452
# log_LAeq_Min       -13.843    6.442 -2.149 0.032  -26.469   -1.217
# sq_LAeq_Min        -15.648    6.181 -2.532 0.011  -27.762   -3.533
# LAeq_Max_LAeq_Min  -22.413    9.536 -2.350 0.019  -41.104   -3.723
# sq_N_5              -0.338    0.145 -2.323 0.020   -0.623   -0.053
# N_10                -5.996    1.138 -5.271 0.000   -8.226   -3.766
# log_N_10             1.721    0.457  3.765 0.000    0.825    2.618
# N_50                 4.207    1.209  3.480 0.001    1.838    6.576
# log_N_50            -3.070    0.861 -3.566 0.000   -4.758   -1.383
# sq_N_50             -1.434    0.628 -2.284 0.022   -2.665   -0.204
# sq_N_90              1.630    0.533  3.057 0.002    0.585    2.675
# log_N_Min            0.730    0.221  3.306 0.001    0.297    1.163
# N_10_N_90            2.479    0.528  4.699 0.000    1.445    3.513
# R_5                 -2.197    0.642 -3.419 0.001   -3.456   -0.938
# log_R_5              1.052    0.344  3.059 0.002    0.378    1.726
# sq_R_5               1.814    0.511  3.551 0.000    0.813    2.815
# log_R_10            -1.453    0.474 -3.065 0.002   -2.382   -0.524
# sq_R_10             -1.964    0.540 -3.640 0.000   -3.021   -0.907
# R_50                -8.997    2.391 -3.763 0.000  -13.683   -4.311
# log_R_50             4.574    1.129  4.052 0.000    2.361    6.786
# sq_R_50              6.615    1.881  3.516 0.000    2.927   10.303
# sq_R_90              2.158    0.719  3.002 0.003    0.749    3.567
# R_95                10.028    3.304  3.035 0.002    3.553   16.504
# log_R_95            -4.514    1.414 -3.192 0.001   -7.285   -1.742
# sq_R_95             -9.437    3.005 -3.140 0.002  -15.328   -3.547
# log_R_Max           -0.067    0.020 -3.294 0.001   -0.107   -0.027
# sq_R_Max             0.100    0.025  3.992 0.000    0.051    0.148
# R_10_R_90            2.399    0.705  3.405 0.001    1.018    3.780
# S                   40.772   14.531  2.806 0.005   12.291   69.253
# log_S              -21.132    7.653 -2.761 0.006  -36.131   -6.133
# sq_S               -22.891    7.678 -2.982 0.003  -37.939   -7.843
# S_5                -15.238    4.761 -3.201 0.001  -24.568   -5.907
# log_S_5             -3.733    1.559 -2.394 0.017   -6.788   -0.677
# sq_S_5              -3.657    1.179 -3.103 0.002   -5.967   -1.347
# log_S_10            10.360    2.236  4.633 0.000    5.977   14.742
# sq_S_10              9.676    1.776  5.449 0.000    6.195   13.156
# S_50               -26.719   12.891 -2.073 0.038  -51.984   -1.453
# log_S_50            13.506    6.684  2.021 0.043    0.405   26.607
# sq_S_50             14.942    6.880  2.172 0.030    1.457   28.427
# log_S_90            -9.400    2.130 -4.412 0.000  -13.575   -5.224
# sq_S_90             -7.576    1.870 -4.051 0.000  -11.242   -3.911
# log_S_95            10.248    2.784  3.681 0.000    4.791   15.704
# sq_S_95              9.449    2.292  4.123 0.000    4.957   13.941
# S_5_S_95            14.640    3.546  4.129 0.000    7.691   21.590
# S_10_S_90          -10.350    2.042 -5.069 0.000  -14.352   -6.348
# SIL_5                8.116    1.228  6.607 0.000    5.708   10.524
# log_SIL_5           -6.213    1.228 -5.061 0.000   -8.619   -3.807
# SIL_50               4.711    1.768  2.665 0.008    1.247    8.176
# sq_SIL_50           -4.374    1.675 -2.611 0.009   -7.657   -1.091
# SIL_Min             -0.791    0.227 -3.479 0.001   -1.237   -0.345
# SIL_Max              1.483    0.409  3.627 0.000    0.682    2.285
# sq_SIL_Max          -1.476    0.387 -3.816 0.000   -2.234   -0.718
# SIL_5_SIL_95        -0.962    0.160 -5.999 0.000   -1.276   -0.648
# sq_T_10              0.059    0.028  2.084 0.037    0.003    0.114
# sq_PeakMaxFreq      -0.046    0.016 -2.941 0.003   -0.076   -0.015
# I_5                -22.368    8.228 -2.718 0.007  -38.495   -6.240
# I_50                 2.905    0.994  2.923 0.003    0.957    4.853
# log_I_50            -1.291    0.563 -2.295 0.022   -2.393   -0.188
# sq_I_50             -1.841    0.509 -3.616 0.000   -2.839   -0.843
# log_I_95             2.097    0.876  2.393 0.017    0.379    3.815
# sq_I_95              2.110    0.702  3.004 0.003    0.733    3.486
# I_Max                1.383    0.389  3.557 0.000    0.621    2.145
# sq_I_Max            -1.190    0.447 -2.662 0.008   -2.066   -0.314
# I_5_I_95            20.579    7.513  2.739 0.006    5.854   35.305
# log_I_10_I_90       -0.181    0.056 -3.199 0.001   -0.291   -0.070
# I_Max_I_Min         -1.219    0.329 -3.706 0.000   -1.864   -0.574
# sq_I_Max_I_Min       1.046    0.384  2.720 0.007    0.292    1.799
# log_LCeq_5         -51.811   20.036 -2.586 0.010  -91.081  -12.542
# sq_LCeq_5          -54.000   18.950 -2.850 0.004  -91.141  -16.858
# LCeq_10           -127.104   45.424 -2.798 0.005 -216.134  -38.074
# log_LCeq_10         60.448   23.496  2.573 0.010   14.396  106.500
# sq_LCeq_10          66.778   22.195  3.009 0.003   23.277  110.279
# LCeq_50              5.538    2.114  2.621 0.009    1.396    9.681
# sq_LCeq_50          -5.239    2.058 -2.546 0.011   -9.272   -1.206
# LCeq_90            113.554   53.126  2.137 0.033    9.428  217.680
# log_LCeq_90        -56.464   27.764 -2.034 0.042 -110.881   -2.047
# sq_LCeq_90         -57.112   26.080 -2.190 0.029 -108.227   -5.997
# log_LCeq_95         48.855   19.170  2.549 0.011   11.284   86.427
# sq_LCeq_95          49.785   17.873  2.786 0.005   14.755   84.814
# LCeq_5_LCeq_95      63.459   23.311  2.722 0.006   17.770  109.148
# LZeq_5            -194.236   41.171 -4.718 0.000 -274.930 -113.542
# log_LZeq_5          96.541   20.758  4.651 0.000   55.857  137.225
# sq_LZeq_5           98.213   20.567  4.775 0.000   57.902  138.523
# log_LZeq_10       -100.435   24.718 -4.063 0.000 -148.881  -51.988
# sq_LZeq_10        -103.500   24.269 -4.265 0.000 -151.067  -55.933
# log_LZeq_90         94.647   22.570  4.193 0.000   50.411  138.883
# sq_LZeq_90          87.392   21.936  3.984 0.000   44.398  130.386
# LZeq_95            267.125   56.310  4.744 0.000  156.760  377.490
# log_LZeq_95       -141.199   29.609 -4.769 0.000 -199.233  -83.166
# sq_LZeq_95        -126.317   27.572 -4.581 0.000 -180.357  -72.278
# log_LZeq_Min        53.897   15.588  3.458 0.001   23.344   84.449
# sq_LZeq_Min         49.849   14.986  3.326 0.001   20.476   79.222
# LZeq_Max          -127.960   37.640 -3.400 0.001 -201.732  -54.187
# LZeq_10_LZeq_90    119.546   28.677  4.169 0.000   63.340  175.752
# LZeq_Max_LZeq_Min  110.480   32.496  3.400 0.001   46.789  174.172
# THD_5                0.144    0.049  2.946 0.003    0.048    0.240
# THD_95              -0.198    0.068 -2.915 0.004   -0.332   -0.065
# THD_10_THD_90       -0.147    0.047 -3.099 0.002   -0.240   -0.054
# LocationID Var       0.005    0.016
# ==================================================================
#
# Adj R-sq:  0.37460027192060996
# AIC:       88.5219853488561
# BIC:       620.1781337552742
#
# ##################################################
# Running Forward step feature selection.
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + LAeq
# Caught a LinAlgError: singular matrix. Skipping LAeq.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + sq_LAeq
# Caught a LinAlgError: singular matrix. Skipping sq_LAeq.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + LAeq
# Caught a LinAlgError: singular matrix. Skipping LAeq.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_LAeq
# Caught a LinAlgError: singular matrix. Skipping sq_LAeq.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + LAeq
# Caught a LinAlgError: singular matrix. Skipping LAeq.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + log_LAeq
# Caught a LinAlgError: singular matrix. Skipping log_LAeq.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_LAeq
# Caught a LinAlgError: singular matrix. Skipping sq_LAeq.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + SIL_5_SIL_95
# Caught a LinAlgError: singular matrix. Skipping SIL_5_SIL_95.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + LCeq_5_LCeq_95
# Caught a LinAlgError: singular matrix. Skipping LCeq_5_LCeq_95.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + LZeq_10_LZeq_90
# Caught a LinAlgError: singular matrix. Skipping LZeq_10_LZeq_90.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + LAeq
# Caught a LinAlgError: singular matrix. Skipping LAeq.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + log_LAeq
# Caught a LinAlgError: singular matrix. Skipping log_LAeq.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_LAeq
# Caught a LinAlgError: singular matrix. Skipping sq_LAeq.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + LAeq_50
# Caught a LinAlgError: singular matrix. Skipping LAeq_50.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + log_LAeq_Min
# Caught a LinAlgError: singular matrix. Skipping log_LAeq_Min.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_LAeq_Min
# Caught a LinAlgError: singular matrix. Skipping sq_LAeq_Min.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + N_50
# Caught a LinAlgError: singular matrix. Skipping N_50.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + log_N_50
# Caught a LinAlgError: singular matrix. Skipping log_N_50.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_N_90
# Caught a LinAlgError: singular matrix. Skipping sq_N_90.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + log_N_Min
# Caught a LinAlgError: singular matrix. Skipping log_N_Min.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + N_10_N_90
# Caught a LinAlgError: singular matrix. Skipping N_10_N_90.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + R_50
# Caught a LinAlgError: singular matrix. Skipping R_50.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + log_R_50
# Caught a LinAlgError: singular matrix. Skipping log_R_50.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_R_50
# Caught a LinAlgError: singular matrix. Skipping sq_R_50.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + log_S_90
# Caught a LinAlgError: singular matrix. Skipping log_S_90.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + log_S_95
# Caught a LinAlgError: singular matrix. Skipping log_S_95.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + S_10_S_90
# Caught a LinAlgError: singular matrix. Skipping S_10_S_90.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + SIL_50
# Caught a LinAlgError: singular matrix. Skipping SIL_50.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_SIL_50
# Caught a LinAlgError: singular matrix. Skipping sq_SIL_50.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + SIL_Min
# Caught a LinAlgError: singular matrix. Skipping SIL_Min.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + SIL_5_SIL_95
# Caught a LinAlgError: singular matrix. Skipping SIL_5_SIL_95.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + log_I_10_I_90
# Caught a LinAlgError: singular matrix. Skipping log_I_10_I_90.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + LCeq_90
# Caught a LinAlgError: singular matrix. Skipping LCeq_90.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + log_LCeq_90
# Caught a LinAlgError: singular matrix. Skipping log_LCeq_90.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_LCeq_90
# Caught a LinAlgError: singular matrix. Skipping sq_LCeq_90.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + log_LCeq_95
# Caught a LinAlgError: singular matrix. Skipping log_LCeq_95.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_LCeq_95
# Caught a LinAlgError: singular matrix. Skipping sq_LCeq_95.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + LCeq_5_LCeq_95
# Caught a LinAlgError: singular matrix. Skipping LCeq_5_LCeq_95.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + LZeq_10_LZeq_90
# Caught a LinAlgError: singular matrix. Skipping LZeq_10_LZeq_90.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_S_90 + LAeq
# Caught a LinAlgError: singular matrix. Skipping LAeq.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_S_90 + log_LAeq
# Caught a LinAlgError: singular matrix. Skipping log_LAeq.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_S_90 + sq_LAeq_10
# Caught a LinAlgError: singular matrix. Skipping sq_LAeq_10.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_S_90 + N_10
# Caught a LinAlgError: singular matrix. Skipping N_10.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_S_90 + R_50
# Caught a LinAlgError: singular matrix. Skipping R_50.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_S_90 + sq_R_50
# Caught a LinAlgError: singular matrix. Skipping sq_R_50.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_S_90 + SIL_5_SIL_95
# Caught a LinAlgError: singular matrix. Skipping SIL_5_SIL_95.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_S_90 + LCeq_90
# Caught a LinAlgError: singular matrix. Skipping LCeq_90.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_S_90 + log_LCeq_90
# Caught a LinAlgError: singular matrix. Skipping log_LCeq_90.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_S_90 + sq_LCeq_90
# Caught a LinAlgError: singular matrix. Skipping sq_LCeq_90.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_S_90 + log_LCeq_95
# Caught a LinAlgError: singular matrix. Skipping log_LCeq_95.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_S_90 + sq_LCeq_95
# Caught a LinAlgError: singular matrix. Skipping sq_LCeq_95.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_S_90 + LCeq_5_LCeq_95
# Caught a LinAlgError: singular matrix. Skipping LCeq_5_LCeq_95.
#
# ############################################################
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_S_90 + LZeq_10_LZeq_90
# Caught a LinAlgError: singular matrix. Skipping LZeq_10_LZeq_90.
#
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_5 + SIL_Max + sq_T_10 + sq_FS + sq_S_90
#           Mixed Linear Model Regression Results
# =========================================================
# Model:             MixedLM  Dependent Variable:  Eventful
# No. Observations:  644      Method:              ML
# No. Groups:        13       Scale:               0.0648
# Min. group size:   11       Log-Likelihood:      -41.2611
# Max. group size:   81       Converged:           Yes
# Mean group size:   49.5
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       0.101    0.022  4.627 0.000  0.058  0.144
# log_LAeq_5     -0.138    0.095 -1.449 0.147 -0.325  0.049
# sq_S           -0.184    0.062 -2.950 0.003 -0.306 -0.062
# FS              0.007    0.021  0.328 0.743 -0.034  0.048
# SIL_5           0.363    0.107  3.379 0.001  0.152  0.574
# SIL_Max        -0.075    0.038 -1.958 0.050 -0.150  0.000
# sq_T_10         0.033    0.013  2.552 0.011  0.008  0.058
# sq_FS          -0.035    0.018 -1.895 0.058 -0.070  0.001
# sq_S_90         0.093    0.058  1.595 0.111 -0.021  0.207
# LocationID Var  0.004    0.009
# =========================================================
#
# Adj R-sq:  0.24893178061432142
# AIC:       104.52214707207713
# BIC:       153.66683305922504
# {'CamdenTown': LocationID    0.105254
# dtype: float64, 'EustonTap': LocationID   -0.045579
# dtype: float64, 'MarchmontGarden': LocationID   -0.071752
# dtype: float64, 'MonumentoGaribaldi': LocationID    0.013889
# dtype: float64, 'PancrasLock': LocationID   -0.035601
# dtype: float64, 'RegentsParkFields': LocationID   -0.057254
# dtype: float64, 'RegentsParkJapan': LocationID    0.042012
# dtype: float64, 'RussellSq': LocationID   -0.032723
# dtype: float64, 'SanMarco': LocationID    0.069463
# dtype: float64, 'StPaulsCross': LocationID   -0.022373
# dtype: float64, 'StPaulsRow': LocationID   -0.044902
# dtype: float64, 'TateModern': LocationID    0.052703
# dtype: float64, 'TorringtonSq': LocationID    0.026863
# dtype: float64}
#
# ##################################################
#
# WARNING: VIF of some features exceeds stated max VIF (10).
# const          1.364244
# log_LAeq_5    62.555458
# sq_S          34.563803
# FS             5.417012
# SIL_5         77.958718
# SIL_Max       10.373942
# sq_T_10        2.089410
# sq_FS          5.515016
# sq_S_90       28.784389
# dtype: float64
#
# Removing SIL_5: 77.95871813503922
# Eventful ~ log_LAeq_5 + sq_S + FS + SIL_Max + sq_T_10 + sq_FS + sq_S_90
#
# Removing sq_S: 28.44169473509077
# Eventful ~ log_LAeq_5 + FS + SIL_Max + sq_T_10 + sq_FS + sq_S_90
# Eventful ~ log_LAeq_5 + FS + SIL_Max + sq_T_10 + sq_FS + sq_S_90
#           Mixed Linear Model Regression Results
# =========================================================
# Model:             MixedLM  Dependent Variable:  Eventful
# No. Observations:  644      Method:              ML
# No. Groups:        13       Scale:               0.0660
# Min. group size:   11       Log-Likelihood:      -48.5593
# Max. group size:   81       Converged:           Yes
# Mean group size:   49.5
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       0.111    0.024  4.621 0.000  0.064  0.158
# log_LAeq_5      0.156    0.039  3.990 0.000  0.079  0.232
# FS             -0.015    0.021 -0.737 0.461 -0.055  0.025
# SIL_Max        -0.041    0.036 -1.126 0.260 -0.112  0.030
# sq_T_10         0.017    0.012  1.398 0.162 -0.007  0.040
# sq_FS          -0.017    0.018 -0.932 0.351 -0.052  0.018
# sq_S_90        -0.054    0.016 -3.425 0.001 -0.085 -0.023
# LocationID Var  0.005    0.011
# =========================================================
#
# Adj R-sq:  0.23778175956990544
# AIC:       115.1186455754314
# BIC:       155.3279341103706
# {'CamdenTown': LocationID    0.122328
# dtype: float64, 'EustonTap': LocationID   -0.026015
# dtype: float64, 'MarchmontGarden': LocationID   -0.08907
# dtype: float64, 'MonumentoGaribaldi': LocationID    0.004803
# dtype: float64, 'PancrasLock': LocationID   -0.041229
# dtype: float64, 'RegentsParkFields': LocationID   -0.07774
# dtype: float64, 'RegentsParkJapan': LocationID    0.02972
# dtype: float64, 'RussellSq': LocationID   -0.031193
# dtype: float64, 'SanMarco': LocationID    0.105053
# dtype: float64, 'StPaulsCross': LocationID   -0.028792
# dtype: float64, 'StPaulsRow': LocationID   -0.048838
# dtype: float64, 'TateModern': LocationID    0.058683
# dtype: float64, 'TorringtonSq': LocationID    0.02229
# dtype: float64}

# %%
plt.scatter(Eventful_model.fittedvalues - Eventful_model.resid, Eventful_model.resid, alpha=0.5)
plt.title("Residual vs. Fitted for Eventful model")
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.show()

# %%
plt.scatter(Eventful_model.fittedvalues, prelockdownData["Eventful"], alpha=0.5)
plt.title("Actual vs. Fitted for Eventful model")
plt.xlabel("Fitted values")
plt.ylabel("Actual values")
plt.show()

# %% [markdown]
# ## Use the models to predict the values for the during lockdown data

# %%
lockdownData["overall_pred"] = overall_model.predict(lockdownData)
lockdownData["Natural_pred"] = Natural_model.predict(lockdownData)
lockdownData["Traffic_pred"] = Traffic_model.predict(lockdownData)
lockdownData["Human_pred"] = Human_model.predict(lockdownData)
lockdownData["Other_pred"] = Other_model.predict(lockdownData)
lockdownData["Pleasant_pred"] = Pleasant_model.predict(lockdownData)
lockdownData["Eventful_pred"] = Eventful_model.predict(lockdownData)

import seaborn as sns
l = sns.pairplot(x_vars=["Pleasant_pred"], y_vars=["Eventful_pred"], data = lockdownData, hue ="LocationID", size = 8)
l.set(xlim = (-1,1))
l.set(ylim= (-1,1))

# %%
p = sns.pairplot(x_vars=["Pleasant"], y_vars=["Eventful"], data = prelockdownData, hue ="LocationID", size = 8)
p.set(xlim = (-1,1))
p.set(ylim= (-1,1))

# %%
prelockdownData["overall_pred"] = overall_model.predict(prelockdownData)
prelockdownData["Natural_pred"] = Natural_model.predict(prelockdownData)
prelockdownData["Traffic_pred"] = Traffic_model.predict(prelockdownData)
prelockdownData["Human_pred"] = Human_model.predict(prelockdownData)
prelockdownData["Other_pred"] = Other_model.predict(prelockdownData)
prelockdownData["Pleasant_pred"] = Pleasant_model.predict(prelockdownData)
prelockdownData["Eventful_pred"] = Eventful_back.predict(prelockdownData)

p = sns.pairplot(x_vars=["Pleasant_pred"], y_vars=["Eventful_pred"], data = prelockdownData, hue ="LocationID", size = 8)
p.set(xlim = (-1,1))
p.set(ylim= (-1,1))

# %% [markdown]
# ## Prediction summary

# %%
prelockdownSummary = prelockdownData[["LocationID", "Eventful", "Eventful_pred", "Pleasant", "Pleasant_pred", "overall", "overall_pred", "Natural", "Natural_pred", "Traffic", "Traffic_pred", "Human", "Human_pred", "Other", "Other_pred"]].groupby(['LocationID']).mean()
prelockdownSummary['LocationID'] = prelockdownSummary.index
prelockdownSummary
# Out:
#                     Eventful  Eventful_pred  Pleasant  Pleasant_pred  \
# LocationID
# CamdenTown          0.389827       0.289674 -0.085017       0.091360
# EustonTap           0.189456       0.254512 -0.212548       0.117813
# MarchmontGarden    -0.045435       0.047784  0.267471       0.361752
# MonumentoGaribaldi  0.057862       0.095492  0.379609       0.422642
# PancrasLock         0.064004       0.100295  0.279305       0.293064
# RegentsParkFields  -0.040805       0.000636  0.466470       0.386439
# RegentsParkJapan   -0.005217      -0.062481  0.636366       0.398887
# RussellSq           0.042110       0.127084  0.486749       0.228311
# SanMarco            0.376335       0.248087  0.187516       0.131233
# StPaulsCross        0.113645       0.148990  0.381169       0.274888
# StPaulsRow          0.120613       0.167427  0.151911       0.198585
# TateModern          0.244340       0.172880  0.349826       0.234088
# TorringtonSq        0.183100       0.105646  0.092297       0.248691
#
#                      overall  overall_pred   Natural  Natural_pred   Traffic  \
# LocationID
# CamdenTown          2.815789      3.317508  1.325146      1.960229  3.825731
# EustonTap           2.684277      3.382415  1.650314      2.064693  3.730189
# MarchmontGarden     3.560256      3.808775  2.625641      2.587474  2.616667
# MonumentoGaribaldi  4.181818      4.072525  2.954545      2.993485  1.772727
# PancrasLock         3.556111      3.700730  2.377315      2.328183  2.385417
# RegentsParkFields   4.280556      3.926903  3.136111      2.852760  2.497222
# RegentsParkJapan    4.617544      3.887981  3.896491      3.157970  1.904386
# RussellSq           4.010937      3.533806  3.340625      2.642032  2.680729
# SanMarco            3.565152      3.455386  2.162626      2.091410  1.386869
# StPaulsCross        3.833333      3.727445  2.308333      2.500340  2.500000
# StPaulsRow          3.614583      3.600462  1.697917      2.251161  2.578125
# TateModern          3.764403      3.526687  2.519547      2.176980  2.650206
# TorringtonSq        3.219828      3.732011  1.994253      2.418485  3.258621
#
#                     Traffic_pred     Human  Human_pred     Other  Other_pred  \
# LocationID
# CamdenTown              2.788431  3.270760    2.993907  2.700000    2.161905
# EustonTap               2.698145  2.535220    2.996006  2.860377    2.135692
# MarchmontGarden         2.854288  2.641026    3.018290  2.407692    2.458686
# MonumentoGaribaldi      2.386435  3.272727    3.113841  1.590909    1.929010
# PancrasLock             2.737088  2.407407    3.069408  3.172454    2.502347
# RegentsParkFields       2.578159  2.880556    2.935790  1.922222    2.405586
# RegentsParkJapan        2.292535  2.500000    3.002889  1.483333    2.147810
# RussellSq               2.423038  2.992708    3.086396  2.044792    2.206197
# SanMarco                2.384318  4.077273    3.291329  1.913636    2.253576
# StPaulsCross            2.663564  3.291667    3.089638  2.025000    2.266069
# StPaulsRow              2.852932  3.354167    3.173397  2.317708    2.432408
# TateModern              2.713599  3.698560    3.264967  2.213992    2.469887
# TorringtonSq            2.535651  3.267241    3.118298  2.839080    2.210374
#
#                             LocationID
# LocationID
# CamdenTown                  CamdenTown
# EustonTap                    EustonTap
# MarchmontGarden        MarchmontGarden
# MonumentoGaribaldi  MonumentoGaribaldi
# PancrasLock                PancrasLock
# RegentsParkFields    RegentsParkFields
# RegentsParkJapan      RegentsParkJapan
# RussellSq                    RussellSq
# SanMarco                      SanMarco
# StPaulsCross              StPaulsCross
# StPaulsRow                  StPaulsRow
# TateModern                  TateModern
# TorringtonSq              TorringtonSq

# %%
lockdownSummary = lockdownData[["LocationID", "Eventful_pred", "Pleasant_pred", "overall_pred", "Natural_pred", "Traffic_pred", "Human_pred", "Other_pred"]].groupby(['LocationID']).mean()
lockdownSummary['LocationID']  = lockdownSummary.index
lockdownSummary
# Out:
#                     Eventful_pred  Pleasant_pred  overall_pred  Natural_pred  \
# LocationID
# CamdenTown               0.261849       0.168480      3.565753      2.066164
# EustonTap                0.225918       0.175083      3.544614      2.093646
# MarchmontGarden          0.009299       0.399435      3.958694      2.690376
# MonumentoGaribaldi       0.085547       0.297214      3.940634      2.871921
# PancrasLock              0.043063       0.312818      3.853252      2.732744
# RegentsParkFields       -0.012345       0.413513      4.024418      2.694242
# RegentsParkJapan        -0.029009       0.339210      3.869485      3.095910
# RussellSq                0.072774       0.351342      3.783883      2.494645
# SanMarco                -0.008632       0.414493      4.032222      2.728850
# StPaulsCross             0.103875       0.322928      3.794737      2.407399
# StPaulsRow               0.143182       0.331291      3.876270      2.562894
# TateModern               0.095731       0.347640      3.851819      2.459882
# TorringtonSq             0.137842       0.304167      3.880106      2.357621
#
#                     Traffic_pred  Human_pred  Other_pred          LocationID
# LocationID
# CamdenTown              2.766678    2.883056    2.382465          CamdenTown
# EustonTap               2.811222    2.906874    2.450315           EustonTap
# MarchmontGarden         2.575367    2.840146    2.508207     MarchmontGarden
# MonumentoGaribaldi      2.377119    3.032138    2.193812  MonumentoGaribaldi
# PancrasLock             2.580567    2.927943    2.419844         PancrasLock
# RegentsParkFields       2.530847    2.887197    2.428794   RegentsParkFields
# RegentsParkJapan        2.254961    2.907743    2.254792    RegentsParkJapan
# RussellSq               2.567390    2.863901    2.587494           RussellSq
# SanMarco                2.410582    2.837881    2.726832            SanMarco
# StPaulsCross            2.671634    2.877808    2.522084        StPaulsCross
# StPaulsRow              2.618066    2.917346    2.591884          StPaulsRow
# TateModern              2.601384    2.908224    2.512105          TateModern
# TorringtonSq            2.589618    2.839723    2.481647        TorringtonSq

# %%
print("Eventful Difference")
print(lockdownSummary["Eventful_pred"] - prelockdownSummary["Eventful"])
print("\nPleasant Difference")
print(lockdownSummary["Pleasant_pred"] - prelockdownSummary["Pleasant"])
print("\noverall Difference")
print(lockdownSummary["overall_pred"] - prelockdownSummary["overall"])
print("\nNatural Difference")
print(lockdownSummary["Natural_pred"] - prelockdownSummary["Natural"])
print("\nTraffic Difference")
print(lockdownSummary["Traffic_pred"] - prelockdownSummary["Traffic"])
print("\nHuman Difference")
print(lockdownSummary["Human_pred"] - prelockdownSummary["Human"])
print("\nOther Difference")
print(lockdownSummary["Other_pred"] - prelockdownSummary["Other"])
# Out:
# Eventful Difference
# LocationID
# CamdenTown           -0.127978
# EustonTap             0.036462
# MarchmontGarden       0.054734
# MonumentoGaribaldi    0.027684
# PancrasLock          -0.020941
# RegentsParkFields     0.028460
# RegentsParkJapan     -0.023792
# RussellSq             0.030663
# SanMarco             -0.384967
# StPaulsCross         -0.009770
# StPaulsRow            0.022569
# TateModern           -0.148609
# TorringtonSq         -0.045258
# dtype: float64
#
# Pleasant Difference
# LocationID
# CamdenTown            0.253496
# EustonTap             0.387631
# MarchmontGarden       0.131964
# MonumentoGaribaldi   -0.082395
# PancrasLock           0.033513
# RegentsParkFields    -0.052956
# RegentsParkJapan     -0.297156
# RussellSq            -0.135406
# SanMarco              0.226977
# StPaulsCross         -0.058241
# StPaulsRow            0.179380
# TateModern           -0.002185
# TorringtonSq          0.211870
# dtype: float64
#
# overall Difference
# LocationID
# CamdenTown            0.749963
# EustonTap             0.860338
# MarchmontGarden       0.398438
# MonumentoGaribaldi   -0.241184
# PancrasLock           0.297141
# RegentsParkFields    -0.256137
# RegentsParkJapan     -0.748059
# RussellSq            -0.227055
# SanMarco              0.467071
# StPaulsCross         -0.038596
# StPaulsRow            0.261687
# TateModern            0.087415
# TorringtonSq          0.660278
# dtype: float64
#
# Natural Difference
# LocationID
# CamdenTown            0.741018
# EustonTap             0.443332
# MarchmontGarden       0.064735
# MonumentoGaribaldi   -0.082624
# PancrasLock           0.355429
# RegentsParkFields    -0.441869
# RegentsParkJapan     -0.800581
# RussellSq            -0.845980
# SanMarco              0.566224
# StPaulsCross          0.099065
# StPaulsRow            0.864977
# TateModern           -0.059666
# TorringtonSq          0.363368
# dtype: float64
#
# Traffic Difference
# LocationID
# CamdenTown           -1.059053
# EustonTap            -0.918966
# MarchmontGarden      -0.041300
# MonumentoGaribaldi    0.604392
# PancrasLock           0.195151
# RegentsParkFields     0.033625
# RegentsParkJapan      0.350575
# RussellSq            -0.113339
# SanMarco              1.023714
# StPaulsCross          0.171634
# StPaulsRow            0.039941
# TateModern           -0.048822
# TorringtonSq         -0.669003
# dtype: float64
#
# Human Difference
# LocationID
# CamdenTown           -0.387704
# EustonTap             0.371654
# MarchmontGarden       0.199120
# MonumentoGaribaldi   -0.240589
# PancrasLock           0.520536
# RegentsParkFields     0.006642
# RegentsParkJapan      0.407743
# RussellSq            -0.128807
# SanMarco             -1.239392
# StPaulsCross         -0.413859
# StPaulsRow           -0.436820
# TateModern           -0.790336
# TorringtonSq         -0.427518
# dtype: float64
#
# Other Difference
# LocationID
# CamdenTown           -0.317535
# EustonTap            -0.410063
# MarchmontGarden       0.100515
# MonumentoGaribaldi    0.602903
# PancrasLock          -0.752610
# RegentsParkFields     0.506571
# RegentsParkJapan      0.771459
# RussellSq             0.542702
# SanMarco              0.813195
# StPaulsCross          0.497084
# StPaulsRow            0.274175
# TateModern            0.298113
# TorringtonSq         -0.357434
# dtype: float64

# %%
ls = sns.pairplot(x_vars=["Pleasant_pred"], y_vars=["Eventful_pred"], data = lockdownSummary, hue="LocationID", size = 8)
ls.set(xlim = (-1,1))
ls.set(ylim= (-1,1))

# %%
ps = sns.pairplot(x_vars=["Pleasant"], y_vars=["Eventful"], data = prelockdownSummary, hue="LocationID", size = 8)
ps.set(xlim = (-1,1))
ps.set(ylim= (-1,1))

# %%
ps = sns.pairplot(x_vars=["Pleasant_pred"], y_vars=["Eventful_pred"], data = prelockdownSummary, hue="LocationID", size = 8)
ps.set(xlim = (-1,1))
ps.set(ylim= (-1,1))
